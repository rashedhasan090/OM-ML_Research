# %%
file_name = input("Enter The File's Name: ")
file_read = open(file_name, "r")
mylist = file_read.readlines()


OM_name = "ecommerce"
om_count = 0 

class1_name = "Customer"
c1_at1 = "customerID"
c1_at1_type = "Integer"

class01_name = "Order"
c01_at1 = "orderID"
c01_at1_type = "Integer"


class2_name = "ShippingCart"
c2_at1 = "shippingCartID"
c2_at1_type = "Integer"


class3_name = "Item"
c3_at1 = "ItemID"
c3_at1_type = "Integer"
c3_at2 = "quantity"
c3_at2_type = "Integer"




class4_name = "CartItem"
c4_at1 = "cartItemID"
c4_at1_type = "Integer"



class5_name = "OrderItem"
c5_at1 = "orderItemID"
c5_at1_type = "Integer"
c5_at2 = "status"
c5_at2_type = "Integer"



class6_name = "Category"
c6_at1 = "categoryID"
c6_at1_type = "Integer"
c6_at2 = "categoryName"
c6_at2_type = "string"





class7_name = "Product"
c7_at1 = "productID"
c7_at1_type = "Integer"
c7_at2 = "productName"
c7_at2_type = "string"
c7_at3 = "description"
c7_at3_type = "string"
c7_at4 = "price"
c7_at4_type = "Real"


class8_name = "Catalog"
c8_at1 = "CatalogID"
c8_at1_type = "Integer"


class9_name = "PhysicalProduct"
c9_at1 = "weight"
c9_at1_type = "Real"
c9_at2 = "availability"
c9_at2_type = "Bool"



class10_name = "ElectronicProduct"
c10_at1 = "size"
c10_at1_type = "string"


class11_name = "Service"
c11_at1 = "schedule"
c11_at1_type = "string"

class12_name = "Asset"
c12_at1 = "assetID"
c12_at1_type = "Integer"
c12_at2 = "assetName"
c12_at2_type = "string"
c12_at3 = "fileURI"
c12_at3_type = "string"



class13_name = "Media"
c13_at1 = "mediaType"
c13_at1_type = "Integer"


class14_name = "Documents"
c14_at1 = "excerpt"
c14_at1_type = "string"



assoc1 = "CustomerOrderAssociation"
assoc2 = "CustomerShippingCartAssociation"
assoc3 = "ShippingCartItemAssociation"
assoc4 = "OrderItemAssociation"
assoc5 = "ProductCategoryAssociation"
assoc6 = "ProductCatalogAssociation"
assoc7 = "ProductItemAssociation"
assoc8 = "ProductAssetAssociation"


src_mlpc = "ONE"
src_mlpc2 = "MANY"
dst_mlpc = "MANY"
dst_mlpc2 = "ONE"

map_str1 = "Union Super Class"
map_str2 = "Union Sub Class"
map_str3 = "Joined Sub Class"

OM_name_0 = "OM_name"
#om_count = 0 

class1_name_0 = "class1_name"
c1_at1_0 = "c1_at1"
c1_at1_type_0 = "c1_at1_type"

class01_name_0 = "class01_name"
c01_at1_0 = "c01_at1"
c01_at1_type_0 = "c01_at1_type"


class2_name_0 = "class2_name"
c2_at1_0 = "c2_at1"
c2_at1_type_0 = "c2_at1_type"





class3_name_0 = "class3_name"
c3_at1_0 = "c3_at1"
c3_at1_type_0 = "c3_at1_type"
c3_at2_0 = "c3_at2"
c3_at2_type_0 = "c3_at2_type"




class4_name_0 = "class4_name"
c4_at1_0 = "c4_at1"
c4_at1_type_0 = "c4_at1_type"



class5_name_0 = "class5_name"
c5_at1_0 = "c5_at1"
c5_at1_type_0 = "c5_at1_type"
c5_at2_0 = "c5_at2"
c5_at2_type_0 = "c5_at2_type"




class6_name_0 = "class6_name"
c6_at1_0 = "c6_at1"
c6_at1_type_0 = "c6_at1_type"
c6_at2_0 = "c6_at2"
c6_at2_type_0 = "c6_at2_type"



class7_name_0 = "class7_name"
c7_at1_0 = "c7_at1"
c7_at1_type_0 = "c7_at1_type"
c7_at2_0 = "c7_at2"
c7_at2_type_0 = "c7_at2_type"
c7_at3_0 = "c7_at3"
c7_at3_type_0 = "c7_at3_type"
c7_at4_0 = "c7_at4"
c7_at4_type_0 = "c7_at4_type"



class8_name_0 = "class8_name"
c8_at1_0 = "c8_at1"
c8_at1_type_0 = "c8_at1_type"



class9_name_0 = "class9_name"
c9_at1_0 = "c9_at1"
c9_at1_type_0 = "c9_at1_type"
c9_at2_0 = "c10_at2"
c9_at2_type_0 = "c10_at2_type"


class10_name_0 = "class10_name"
c10_at1_0 = "c10_at1"
c10_at1_type_0 = "c10_at1_type"



class11_name_0 = "class11_name"
c11_at1_0 = "c11_at1"
c11_at1_type_0 = "c11_at1_type"

class12_name_0 = "class12_name"
c12_at1_0 = "c12_at1"
c12_at1_type_0 = "c12_at1_type"
c12_at2_0 = "c12_at2"
c12_at2_type_0 = "c12_at2_type"
c12_at3_0 = "c12_at3"
c12_at3_type_0 = "c12_at3_type"



class13_name_0 = "class13_name"
c13_at1_0 = "c13_at1"
c13_at1_type_0 = "c13_at1_type"


class14_name_0 = "class14_name"
c14_at1_0 = "c14_at1"
c14_at1_type_0 = "c14_at1_type"




assoc1_0 = "assoc1"
assoc2_0 = "assoc2"
assoc3_0 = "assoc3"
assoc4_0 = "assoc4"
assoc5_0 = "assoc5"
assoc6_0 = "assoc6"
assoc7_0 = "assoc7"
assoc8_0 = "assoc8"


src_mlpc_0 = "src_mlpc"
dst_mlpc_0 = "dst_mlpc"
src_mlpc2_0 = "src_mlpc2"
dst_mlpc2_0 = "dst_mlpc2"


map_str1_0 = "map_str1"
map_str2_0 = "map_str2"
map_str3_0 = "map_str3"


#start from here 

file_object = open(f'Ecommerce_OM_Abstract_only.txt', 'a')


for j in range(len(mylist)):
    
    if f"module {OM_name}" in mylist[j]:
        mylist[j] = (f"module {OM_name_0}: {om_count},")
        a0 = mylist[j]
        file_object.write(a0)
        file_object.write("\n")
        om_count += 1
        
    
    if f'one sig {class1_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class1_name_0} extends Class')
        a1 = mylist[j]
        file_object.write(a1)
        file_object.write("\n")
        
        
    if f'attrSet = {c1_at1}' in mylist[j]:
        
        mylist[j] = (f"attrSet = {c1_at1_0}")
        a2 = mylist[j]
        file_object.write(a2)
        file_object.write("\n")
        
    if f'id={c1_at1}' in mylist[j]:
        
        mylist[j] = (f'id={c1_at1_0}')
        a3 = mylist[j]
        file_object.write(a3)
        file_object.write("\n")
        
        
    if f'isAbstract = No' in mylist[j]:
        
        mylist[j] = ('isAbstract = No')
        a4 = mylist[j]
        file_object.write(a4)
        file_object.write("\n")
        
        
        
    if f'no parent' in mylist[j]:
        
        mylist[j] = ('no parent')
        a5 = mylist[j]
        file_object.write(a5)
        file_object.write("\n")
        
        
    if f'one sig {c1_at1} extends {c1_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c1_at1_0} extends {c1_at1_type_0},')
        a6 = mylist[j]
        file_object.write(a6)
        file_object.write("\n")  
        file_object.write("\n")
        
        
        
  #-----------------------------------------------------------------------------------------


    if f'one sig {class01_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class01_name_0} extends Class')
        a01 = mylist[j]
        file_object.write(a01)
        file_object.write("\n")
        
        
    if f'attrSet = {c01_at1}' in mylist[j]:
        
        mylist[j] = (f"attrSet = {c01_at1_0}")
        a02 = mylist[j]
        file_object.write(a02)
        file_object.write("\n")
        
    if f'id={c01_at1}' in mylist[j]:
        
        mylist[j] = (f'id={c01_at1_0}')
        a03 = mylist[j]
        file_object.write(a03)
        file_object.write("\n")
        
        
        
        
    if f'one sig {c01_at1} extends {c01_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c01_at1_0} extends {c01_at1_type_0},')
        a06 = mylist[j]
        file_object.write(a06)
        file_object.write("\n")  
        file_object.write("\n")
       
 #-------------------------------------------------------------------------------------------
        
    if f'one sig {class2_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class2_name_0} extends Class')
        a8 = mylist[j]
        file_object.write(a8)
        file_object.write("\n")
        
        
    if f'attrSet = {c2_at1}' in mylist[j]:
        
        mylist[j] = (f"attrSet = {c2_at1_0}")
        a9 = mylist[j]
        file_object.write(a9)
        file_object.write("\n")
        
    if f'id={c2_at1}' in mylist[j]:
        
        mylist[j] = (f"id = {c2_at1_0}")
        a10 = mylist[j]
        file_object.write(a10)
        file_object.write("\n")
        
        
        
    if f'one sig {c2_at1} extends {c2_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c2_at1_0} extends {c2_at1_type_0},')
        a11 = mylist[j]
        file_object.write(a11)
        file_object.write("\n")  
        file_object.write("\n")
        
        
        
  #-----------------------------------------------------------------------
    if f'one sig {assoc1} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc1_0} extends Association')
        a015 = mylist[j]
        file_object.write(a015)
        file_object.write("\n")
        
        
    if f'src = {class1_name}' in mylist[j]:

        mylist[j] = (f"src = {class1_name_0}")
        a016 = mylist[j]
        file_object.write(a016)
        file_object.write("\n")
        
        
    if f'dst = {class2_name}' in mylist[j]:

        mylist[j] = (f"dst = {class2_name_0}")
        a017 = mylist[j]
        file_object.write(a017)
        file_object.write("\n")

  #------------------------------------------------------------------------      
        
        
    if f'one sig {assoc2} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc2_0} extends Association')
        a15 = mylist[j]
        file_object.write(a15)
        file_object.write("\n")
        
        
        
        
    if f'dst = {class01_name}' in mylist[j]:

        mylist[j] = (f"dst = {class01_name_0}")
        a17 = mylist[j]
        file_object.write(a17)
        file_object.write("\n")


        
    #--------------------------------------------------------------------
        
    if f'one sig {class3_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class3_name_0} extends Class')
        a21 = mylist[j]
        file_object.write(a21)
        file_object.write("\n")
        
        
    if f'attrSet = {c3_at1}+{c3_at2}' in mylist[j]:

        mylist[j] = (f"attrSet = {c3_at1_0}+{c3_at2_0}")
        a22 = mylist[j]
        file_object.write(a22)
        file_object.write("\n")
        
        
    if f'id={c3_at1}' in mylist[j]:

        mylist[j] = (f"id={c3_at1_0}")
        a23 = mylist[j]
        file_object.write(a23)
        file_object.write("\n")
        

    if f'one sig {c3_at1} extends {c3_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c3_at1_0} extends {c3_at1_type_0}')
        a24 = mylist[j]
        file_object.write(a24)
        file_object.write("\n") 
        
    if f'one sig {c3_at2} extends {c3_at2_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c3_at2_0} extends {c3_at2_type_0},')
        a25 = mylist[j]
        file_object.write(a25)
        file_object.write("\n") 
        

   
    #---------------------------------------------------------------------     
    if f'one sig {class4_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class4_name_0} extends Class')
        a28 = mylist[j]
        file_object.write(a28)
        file_object.write("\n")
        
        
    if f'attrSet = {c4_at1}' in mylist[j]:

        mylist[j] = (f"attrSet = {c4_at1_0}")
        a29 = mylist[j]
        file_object.write(a29)
        file_object.write("\n")
        
        
    if f'parent in {class3_name}' in mylist[j]:

        mylist[j] = (f"parent in {class3_name_0}")
        a030 = mylist[j]
        file_object.write(a030)
        file_object.write("\n")
        
    if f'id={c4_at1}' in mylist[j]:

        mylist[j] = (f"id={c4_at1_0}")
        a30 = mylist[j]
        file_object.write(a30)
        file_object.write("\n")    


    if f'one sig {c4_at1} extends {c4_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c4_at1_0} extends {c4_at1_type_0},')
        a31 = mylist[j]
        file_object.write(a31)
        file_object.write("\n") 
        
 
        
        
    #------------------------------------------------------------------
            
    if f'one sig {assoc3} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc3_0} extends Association')
        a125 = mylist[j]
        file_object.write(a125)
        file_object.write("\n")
        
        
    if f'src = {class2_name}' in mylist[j]:

        mylist[j] = (f"dst = {class2_name_0}")
        a126 = mylist[j]
        file_object.write(a126)
        file_object.write("\n")
       
        
    if f'dst = {class3_name}' in mylist[j]:

        mylist[j] = (f"dst = {class3_name_0}")
        a127 = mylist[j]
        file_object.write(a127)
        file_object.write("\n")
    
    
    
    
    #----------------------------------------------------------------
    
    if f'one sig {class5_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class5_name_0} extends Class')
        a028 = mylist[j]
        file_object.write(a028)
        file_object.write("\n")
        
        
    if f'attrSet = {c5_at1}+{c5_at2}' in mylist[j]:

        mylist[j] = (f"attrSet = {c5_at1_0}+{c5_at2_0}")
        a029 = mylist[j]
        file_object.write(a029)
        file_object.write("\n")
        
        
    if f'id={c3_at1}' in mylist[j]:

        mylist[j] = (f"id={c3_at1_0}")
        a030 = mylist[j]
        file_object.write(a030)
        file_object.write("\n")
        
    if f'parent in {class3_name}' in mylist[j]:

        mylist[j] = (f"parent in {class3_name_0}")
        a030 = mylist[j]
        file_object.write(a030)
        file_object.write("\n")   
        


    if f'one sig {c5_at1} extends {c5_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c5_at1_0} extends {c5_at1_type_0}')
        a031 = mylist[j]
        file_object.write(a031)
        file_object.write("\n") 
        
        
    if f'one sig {c5_at2} extends {c5_at2_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c5_at2_0} extends {c5_at2_type_0}')
        a032 = mylist[j]
        file_object.write(a032)
        file_object.write("\n") 
        
        
        
        
    #----------------------------------------------------------------------

    
  
    if f'one sig {assoc4} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc4_0} extends Association')
        a0028 = mylist[j]
        file_object.write(a0028)
        file_object.write("\n")
        
        
    if f'src = {class01_name}' in mylist[j]:

        mylist[j] = (f"src = {class01_name_0}")
        a0029 = mylist[j]
        file_object.write(a0029)
        file_object.write("\n")
        
        
    if f'dst = {class3_name}' in mylist[j]:

        mylist[j] = (f"dst = {class3_name_0}")
        a0030 = mylist[j]
        file_object.write(a0030)
        file_object.write("\n")
        
   
    #------------------------------------- ------------------------------ -------------- -------------
     
    if f'one sig {class6_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class6_name_0} extends Class')
        a33 = mylist[j]
        file_object.write(a33)
        file_object.write("\n") 
        
        
    if f'attrSet = {c6_at1}+{c6_at2}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c6_at1_0}+{c6_at2_0}')
        a34 = mylist[j]
        file_object.write(a34)
        file_object.write("\n")  
        
    if f'id={c6_at1}' in mylist[j]:
        
        mylist[j] = (f'id={c6_at1}')
        a35 = mylist[j]
        file_object.write(a35)
        file_object.write("\n")
        
    if f'one sig {c6_at1} extends {c6_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c6_at1_0} extends {c6_at1_type_0}')
        a035 = mylist[j]
        file_object.write(a035)
        file_object.write("\n")   
        
        
    if f'one sig {c6_at2} extends {c6_at2_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c6_at2_0} extends {c6_at2_type_0}')
        a0035 = mylist[j]
        file_object.write(a0035)
        file_object.write("\n")  
        
    
    #----------------------------------------------------------------------
    if f'one sig {class7_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class7_name_0} extends Class')
        a36 = mylist[j]
        file_object.write(a36)
        file_object.write("\n") 
        

    
    if f'attrSet = {c7_at1}+{c7_at2}+{c7_at3}+{c7_at4}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c7_at1_0}+{c7_at2_0}+{c7_at3_0}+{c7_at4_0}')
        a201 = mylist[j]
        file_object.write(a201)
        file_object.write("\n")
        
    if f'id={c7_at1}' in mylist[j]:
        
        mylist[j] = (f'id={c7_at1_0}')
        a202 = mylist[j]
        file_object.write(a202)
        file_object.write("\n")    
        
        
    if f'one sig {c7_at1} extends {c7_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c7_at1_0} extends {c7_at1_type_0}')
        a203 = mylist[j]
        file_object.write(a203)
        file_object.write("\n")   
        
    if f'one sig {c7_at2} extends {c7_at2_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c7_at2_0} extends {c7_at2_type_0}')
        a204 = mylist[j]
        file_object.write(a204)
        file_object.write("\n")  
        
        
    if f'one sig {c7_at3} extends {c7_at3_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c7_at3_0} extends {c7_at3_type_0}')
        a205 = mylist[j]
        file_object.write(a205)
        file_object.write("\n")  
        
        
    if f'one sig {c7_at4} extends {c7_at4_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c7_at4_0} extends {c7_at4_type_0}')
        a206 = mylist[j]
        file_object.write(a206)
        file_object.write("\n")     
        
    
    #----------------------------------------------------------------------
        
    if f'one sig {assoc5} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc5_0} extends Association')
        a39 = mylist[j]
        file_object.write(a39)
        file_object.write("\n") 
        
        
    if f'src = {class7_name}' in mylist[j]:
        
        mylist[j] = (f'src = {class7_name_0}')
        a40 = mylist[j]
        file_object.write(a40)
        file_object.write("\n")  
        

    if f'dst = {class6_name}' in mylist[j]:
        
        mylist[j] = (f'src = {class6_name_0}')
        a41 = mylist[j]
        file_object.write(a41)
        file_object.write("\n")  
        
        
        
 #----------------------------------------------------------------------
        
    if f'one sig {class8_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class8_name_0} extends Class')
        a42 = mylist[j]
        file_object.write(a42)
        file_object.write("\n") 
        
    if f'attrSet = {c8_at1}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c8_at1_0}')
        a142 = mylist[j]
        file_object.write(a142)
        file_object.write("\n")     
        
    if f'id={c8_at1}' in mylist[j]:
        
        mylist[j] = (f'id={c8_at1_0}')
        a143 = mylist[j]
        file_object.write(a143)
        file_object.write("\n")   
        
        
        
    if f'one sig {c8_at1} extends Integer' in mylist[j]:
        
        mylist[j] = (f'one sig {c8_at1_0} extends Integer')
        a144 = mylist[j]
        file_object.write(a144)
        file_object.write("\n") 
        
#--------------------- ---------------------- -------------------------
    
    if f'one sig {assoc6} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc6_0} extends Association')
        a144 = mylist[j]
        file_object.write(a144)
        file_object.write("\n") 
        
        
        
    if f'src = {class7_name}' in mylist[j]:
        
        mylist[j] = (f'src = {class7_name_0}')
        a145 = mylist[j]
        file_object.write(a145)
        file_object.write("\n") 
        
        
        
    if f'dst = {class8_name}' in mylist[j]:
        
        mylist[j] = (f'dst = {class8_name_0}')
        a146 = mylist[j]
        file_object.write(a146)
        file_object.write("\n") 
        
        
    if f'one sig {assoc7} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc7_0} extends Association')
        a184 = mylist[j]
        file_object.write(a184)
        file_object.write("\n") 
        
#--------------------------------------------------------------------------
    if f'one sig {class9_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class9_name_0} extends Class')
        a147 = mylist[j]
        file_object.write(a147)
        file_object.write("\n") 
        
        

        
    if f'attrSet = {c9_at1}+{c9_at2}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c9_at1_0}+{c9_at2_0}')
        a148 = mylist[j]
        file_object.write(a148)
        file_object.write("\n") 
        
        
    if f'id={c9_at1}' in mylist[j]:
        
        mylist[j] = (f'id={c9_at1_0}')
        a149 = mylist[j]
        file_object.write(a149)
        file_object.write("\n") 
        
        
    if f'parent in {class7_name}' in mylist[j]:
        
        mylist[j] = (f'parent in {class7_name_0}')
        a150 = mylist[j]
        file_object.write(a150)
        file_object.write("\n") 
        
        
        
    if f'one sig {c9_at1} extends {c9_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c9_at1_0} extends {c9_at1_type_0}')
        a151 = mylist[j]
        file_object.write(a151)
        file_object.write("\n") 
        
        
        
    if f'one sig {c9_at2} extends {c9_at2_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c9_at2_0} extends {c9_at2_type_0}')
        a152 = mylist[j]
        file_object.write(a152)
        file_object.write("\n") 
        



#----------------------------------------------------------------------
        
    
    if f'one sig {class10_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class10_name_0} extends Class')
        a153 = mylist[j]
        file_object.write(a153)
        file_object.write("\n") 
        
        
    if f'attrSet = {c10_at1}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c10_at1_0}')
        a154 = mylist[j]
        file_object.write(a154)
        file_object.write("\n")
        
        
        
    if f'one sig {c10_at1} extends {c10_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c10_at1_0} extends {c10_at1_type_0}')
        a155 = mylist[j]
        file_object.write(a155)
        file_object.write("\n")
        
#---------------------------------------------------------------------

   
    if f'one sig {class11_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class11_name_0} extends Class')
        a156 = mylist[j]
        file_object.write(a156)
        file_object.write("\n") 
        
        
    if f'attrSet = {c11_at1}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c11_at1_0}')
        a157 = mylist[j]
        file_object.write(a157)
        file_object.write("\n")
        
        
        
    if f'one sig {c11_at1} extends string' in mylist[j]:
        
        mylist[j] = (f'one sig {c11_at1_0} extends string')
        a158 = mylist[j]
        file_object.write(a158)
        file_object.write("\n")
        


#---------------------------------------------------------------------

    if f'one sig {class12_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class12_name_0} extends Class')
        a159 = mylist[j]
        file_object.write(a159)
        file_object.write("\n") 
        
        
    if f'attrSet = {c12_at1}+{c12_at2}+{c12_at3}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c12_at1_0}+{c12_at2_0}+{c12_at3_0}')
        a160 = mylist[j]
        file_object.write(a160)
        file_object.write("\n")
        
        
    if f'id = {c12_at1}' in mylist[j]:
        
        mylist[j] = (f'id = {c12_at1_0}')
        a162 = mylist[j]
        file_object.write(a162)
        file_object.write("\n")
        
        
    if f'one sig {c12_at2} extends {c12_at2_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c12_at2_0} extends {c12_at2_type_0}')
        a161 = mylist[j]
        file_object.write(a161)
        file_object.write("\n")
        
        
        
    if f'one sig {c12_at1} extends {c12_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c12_at1_0} extends {c12_at1_type_0}')
        a163 = mylist[j]
        file_object.write(a163)
        file_object.write("\n")
        
        
        
    if f'one sig {c12_at3} extends {c12_at3_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c12_at3_0} extends {c12_at3_type_0}')
        a164 = mylist[j]
        file_object.write(a164)
        file_object.write("\n")
        
        
        #start from here ProductAssetAssociation .... 
#---------------------------------------------------------------

    if f'one sig {assoc8} extends Association' in mylist[j]:
        
        mylist[j] = (f'one sig {assoc8_0} extends Association')
        a165 = mylist[j]
        file_object.write(a165)
        file_object.write("\n")
        
        
    if f'src = {class7_name}' in mylist[j]:
        
        mylist[j] = (f'src = {class7_name_0}')
        a166 = mylist[j]
        file_object.write(a166)
        file_object.write("\n")     

    if f'dst = {class12_name}' in mylist[j]:
        
        mylist[j] = (f'src = {class12_name_0}')
        a167 = mylist[j]
        file_object.write(a167)
        file_object.write("\n") 


#--------------------------------------------------------------------




    if f'one sig {class13_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class13_name_0} extends Class')
        a165 = mylist[j]
        file_object.write(a165)
        file_object.write("\n")
        
        
        
    if f'attrSet = {c13_at1}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c13_at1_0}')
        a166 = mylist[j]
        file_object.write(a166)
        file_object.write("\n")
        
        
    if f'id = {c12_at1}' in mylist[j]:
        
        mylist[j] = (f'id = {c12_at1_0}')
        a167 = mylist[j]
        file_object.write(a167)
        file_object.write("\n")
        
    if f'parent in {class12_name}' in mylist[j]:
        
        mylist[j] = (f'parent in {class12_name_0}')
        a168 = mylist[j]
        file_object.write(a168)
        file_object.write("\n")
        
        
    if f'one sig {c13_at1} extends {c13_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c13_at1_0} extends {c13_at1_type_0}')
        a0169 = mylist[j]
        file_object.write(a0169)
        file_object.write("\n")
        
        
   
    
    if f'one sig {class14_name} extends Class' in mylist[j]:
        
        mylist[j] = (f'one sig {class14_name_0} extends Class')
        a169 = mylist[j]
        file_object.write(a169)
        file_object.write("\n")
        
        
        
    if f'attrSet = {c14_at1}' in mylist[j]:
        
        mylist[j] = (f'attrSet = {c14_at1_0}')
        a170 = mylist[j]
        file_object.write(a170)
        file_object.write("\n")    
        
    if f'one sig {c14_at1} extends {c14_at1_type}' in mylist[j]:
        
        mylist[j] = (f'one sig {c14_at1_0} extends {c14_at1_type_0}')
        a171 = mylist[j]
        file_object.write(a171)
        file_object.write("\n")   
           

#---------------------------------------- ---------------------
        
    if f'src_multiplicity = {src_mlpc}' in mylist[j]:
        
        mylist[j] = (f'src_multiplicity = {src_mlpc_0}')
        a43 = mylist[j]
        file_object.write(a43)
        file_object.write("\n")


        
    if f'src_multiplicity = {src_mlpc2}' in mylist[j]:
        
        mylist[j] = (f'src_multiplicity = {src_mlpc2_0}')
        a043 = mylist[j]
        file_object.write(a043)
        file_object.write("\n")
        
    if f'dst_multiplicity = {dst_mlpc}' in mylist[j]:
        
        mylist[j] = (f'dst_multiplicity = {dst_mlpc_0},')
        a044 = mylist[j]
        file_object.write(a044)
        file_object.write("\n")
        
    if f'dst_multiplicity = {dst_mlpc2}' in mylist[j]:
        
        mylist[j] = (f'dst_multiplicity = {dst_mlpc2_0},')
        a48 = mylist[j]
        file_object.write(a48)
        file_object.write("\n")   
        
         
        
    if f'one parent' in mylist[j]:
        
        mylist[j] = (f'one parent')
        a45 = mylist[j]
        file_object.write(a45)
        file_object.write("\n")
        
  
        
        
    if f'pred show' in mylist[j]:
        
        mylist[j] = (f'pred show')
        a46 = mylist[j]
        file_object.write(a46)
        file_object.write("\n")
        
        
    if f'run show for 48' in mylist[j]:
        
        mylist[j] = (f'run show')
        a47 = mylist[j]
        file_object.write(a47)
        file_object.write("\n")
        file_object.close() 
        
        
    
    # no need to use replace if you're going to change the whole string

        
#print(mylist)

for  x in range(len(mylist)) :
   
    print(mylist[x]) 
    x += 1
# Out:
# Enter The File's Name: ecommerce.als
# module OM_name: 0,
# open Declaration
#
#
#
# one sig class1_name extends Class
# attrSet = c1_at1
# id=c1_at1
# isAbstract = No
# no parent
# }
#
#
#
# one sig c1_at1 extends c1_at1_type,
#
#
#
#
# one sig class01_name extends Class
# attrSet = c01_at1
# id=c01_at1
# isAbstract = No
# no parent
# }
#
#
#
# one sig c01_at1 extends c01_at1_type,
#
#
#
#
# one sig assoc1 extends Association
# src = class1_name
# dst = class01_name
# src_multiplicity = src_mlpc
# dst_multiplicity = dst_mlpc,
# }
#
#
#
# one sig class2_name extends Class
# attrSet = c2_at1
# id = c2_at1
# isAbstract = No
# no parent
# }
#
#
#
# one sig c2_at1 extends c2_at1_type,
#
#
#
#
# one sig assoc2 extends Association
# src = class1_name
# dst = class2_name
# src_multiplicity = src_mlpc
# dst_multiplicity = dst_mlpc,
# }
#
#
#
#
#
# one sig class3_name extends Class
# attrSet = c3_at1+c3_at2
# id=c3_at1
# isAbstract = No
# no parent
# }
#
#
#
# ...
