# %% [markdown]
# # Transformer based distributed training
#
# Transformer based distributed training - 50P - 50NP_exp_1.ipynb
# 50P- 50NP : Experiment 1
#
#
# ## Object Models: 15
#
# 1.	Bank
# 2.	Camping
# 3.	Canteen
# 4.	Customer_Order
# 5.	Ecommerce
# 6.	Hospital Management
# 7.	Library Management
# 8.	Onlinestore
# 9.	Student Course
# 10.	Traffic_Controller
# 11.	University
# 12.	Decider
# 13.	School_mgmt
# 14.	Store_mgmt
# 15. Credit Card Process
#
#
# ## Dataset Instances: 31139
#
#
# ## Total Training Data: 26470
#
# ### training set P :  12616
#
# ### training set NP : 13854
#
#
# ## Total Testing Data: 4670
#
#
# ### testing set P : 703
#
# ### testing set NP : 3967

# %% [markdown]
# ## Introduction
#
# In this example, we'll build a sequence-to-sequence Transformer model, which
# we'll train on an English-to-Spanish machine translation task.
#
# You'll learn how to:
#
# - Vectorize text using the Keras `TextVectorization` layer.
# - Implement a `TransformerEncoder` layer, a `TransformerDecoder` layer,
# and a `PositionalEmbedding` layer.
# - Prepare data for training a sequence-to-sequence model.
# - Use the trained model to generate translations of never-seen-before
# input sentences (sequence-to-sequence inference).
#
# The code featured here is adapted from the book
# [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition)
# (chapter 11: Deep learning for text).
# The present example is fairly barebones, so for detailed explanations of
# how each building block works, as well as the theory behind Transformers,
# I recommend reading the book.

# %% [markdown]
# ## Setup

# %%
import pathlib
import random
import string
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %%
## Using Mirrored Strategy for Distributed Training

# %%
# Enable mixed precision for better performance on GPUs with Tensor Cores
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Check the number of available GPUs
gpus = tf.config.list_physical_devices('GPU')
num_gpus = len(gpus)
if num_gpus > 1:
    # Enable mirrored strategy for distributed training
    strategy = tf.distribute.MirroredStrategy()
    print('Running distributed training on', num_gpus, 'GPUs.')
else:
    strategy = tf.distribute.get_strategy()
    print('Running training on a single GPU.')
# Out:
# Running training on a single GPU.

# %% [markdown]
# ## Downloading the data
#
# We'll be working with an English-to-Spanish translation dataset
# provided by [Anki](https://www.manythings.org/anki/). Let's download it:

# %%
# !unzip new.zip

import pathlib

file_path = "/content/new.zip"
extracted_dir = pathlib.Path(file_path).parent
text_file = extracted_dir / "15_OM_50_final_1.txt"
# Out:
# Archive:  new.zip
#   inflating: 15_OM_50_final_1.txt

# %% [markdown]
# ## Parsing the data
#
# Each line contains an English sentence and its corresponding Spanish sentence.
# The English sentence is the *source sequence* and Spanish one is the *target sequence*.
# We prepend the token `"[start]"` and we append the token `"[end]"` to the Spanish sentence.

# %%
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    eng, spa = line.split("\t")
    spa = "[start] " + spa + " [end]"
    text_pairs.append((eng, spa))

# %% [markdown]
# Here's what our sentence pairs look like:

# %%
for _ in range(5):
    print(random.choice(text_pairs))
# Out:
# ("module OM_name0 ;openDeclaration one sig class1_name extends ClassattrSet=c1_at1+c1_at2id=c1_at1noparentisAbstract=No} one sig c1_at1 extends c1_at1_type one sig c1_at2 extends c1_at2_type one sig class2_name extends ClassattrSet=c2_at1+c2_at2id=c2_at1noparentisAbstract=No} one sig c2_at1 extends c2_at1_type one sig c2_at1 extends c2_at2_type one sig class3_name extends ClassattrSet=c3_at1+c3_at2+c3_at3+c3_at4c3_at5+c3_at6id=c3_at1noparentisAbstract=No} one sig c3_at1 extends c3_at1_type one sig c3_at2 extends c3_at2_type one sig c3_at3 extends c3_at3_type one sig c3_at4 extends c3_at4_type one sig c3_at5 extends c3_at5_type one sig c3_at6 extends c3_at6_type one sig class4_name extends ClassattrSet=c4_at1+c4_at2+c4_at3+c4_at4id=c4_at3noparentisAbstract=No} one sig c4_at1 extends c4_at1_type one sig c4_at2 extends c4_at2_type one sig c4_at3 extends c4_at3_type one sig c4_at4 extends c4_at4_type one sig class5_name extends ClassattrSet=c5_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c5_at1 extends c5_at1_type one sig class6_name extends ClassattrSet=c6_at1_0+c6_at2+c6_at3+c6_at4id=c6_at2noparentisAbstract=No} one sig c6_at1_0 extends c6_at1_type one sig c6_at2 extends c6_at2_type one sig c6_at3 extends c6_at3_type one sig c6_at4 extends c6_at4_type one sig class7_name extends ClassattrSet=c7_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c7_at1 extends c7_at1_type one sig class8_name extends ClassattrSet=c8_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c8_at1 extends c8_at1_type one sig class9_name extends ClassattrSet=c9_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c9_at1 extends c9_at1_type one sig class10_name extends ClassattrSet=c10_at1+c10_at2+c2_at2+c6_at3id=c10_at1noparentisAbstract=No} one sig c10_at1 extends c10_at1_type one sig c10_at2 extends c10_at2_type one sig assoc10 extends  Association src=class10_namedst=class2_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc1 extends  Association src=class2_namedst=class4_name src_multiplicity =src_mlpc2 dst_multiplicity =dst_mlpc} one sig assoc2 extends  Association src=class10_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc3 extends  Association src=class10_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc4 extends  Association src=class10_namedst=class6_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} one sig assoc5 extends  Association src=class6_namedst=class1_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} one sig assoc6 extends  Association src=class6_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc7 extends  Association src=class1_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc8 extends  Association src=class1_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc9 extends  Association src=class2_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} pred show run show ,MappingStrategyforclass1_name:map_str2MappingStrategyforclass5_name:map_str2MappingStrategyforclass6_name:map_str2MappingStrategyforclass7_name:map_str3MappingStrategyforclass8_name:map_str3AssociationStrategyforassoc6:assoc_str1AssociationStrategyforassoc7:assoc_str1AssociationStrategyforassoc1:assoc_str2AssociationStrategyforassoc2:assoc_str2AssociationStrategyforassoc3:assoc_str2AssociationStrategyforassoc4:assoc_str2AssociationStrategyforassoc5:assoc_str2AssociationStrategyforassoc9:assoc_str2,USEOM_name:0;CREATE TABLE `class7_name`(`c7_at1`c7_at1_type(64),`c2_at2`c2_at2_type(64),`c2_at1`c2_at1_typeNOT NULL, PRIMARY  KEY  (`c2_at1`)CREATE TABLE `class5_name`(c5_at1`c5_at1_type(64),`c2_at2`c2_at2_type(64),`c2_at1`c2_at1_typeNOT NULL, PRIMARY  KEY  (`c2_at1`)CREATE TABLE `assoc3`(c10_at1`c10_at1_type`c4_at3`c4_at3_typeNOT NULL,CREATE TABLE `class2_name` ...
# ('module OM_name0 ;openDeclaration one sig class1_name extends ClassattrSet=c1_at1+c1_at2id=c1_at1noparentisAbstract=No} one sig c1_at1 extends c1_at1_type one sig c1_at2 extends c1_at2_type one sig class2_name extends ClassattrSet=c2_at1+c2_at2id=c2_at1noparentisAbstract=No} one sig c2_at1 extends c2_at1_type one sig c2_at1 extends c2_at2_type one sig class3_name extends ClassattrSet=c3_at1+c3_at2+c3_at3+c3_at4c3_at5+c3_at6id=c3_at1noparentisAbstract=No} one sig c3_at1 extends c3_at1_type one sig c3_at2 extends c3_at2_type one sig c3_at3 extends c3_at3_type one sig c3_at4 extends c3_at4_type one sig c3_at5 extends c3_at5_type one sig c3_at6 extends c3_at6_type one sig class4_name extends ClassattrSet=c4_at1+c4_at2+c4_at3+c4_at4id=c4_at3noparentisAbstract=No} one sig c4_at1 extends c4_at1_type one sig c4_at2 extends c4_at2_type one sig c4_at3 extends c4_at3_type one sig c4_at4 extends c4_at4_type one sig class5_name extends ClassattrSet=c5_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c5_at1 extends c5_at1_type one sig class6_name extends ClassattrSet=c6_at1_0+c6_at2+c6_at3+c6_at4id=c6_at2noparentisAbstract=No} one sig c6_at1_0 extends c6_at1_type one sig c6_at2 extends c6_at2_type one sig c6_at3 extends c6_at3_type one sig c6_at4 extends c6_at4_type one sig class7_name extends ClassattrSet=c7_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c7_at1 extends c7_at1_type one sig class8_name extends ClassattrSet=c8_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c8_at1 extends c8_at1_type one sig class9_name extends ClassattrSet=c9_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c9_at1 extends c9_at1_type one sig class10_name extends ClassattrSet=c10_at1+c10_at2+c2_at2+c6_at3id=c10_at1noparentisAbstract=No} one sig c10_at1 extends c10_at1_type one sig c10_at2 extends c10_at2_type one sig assoc10 extends  Association src=class10_namedst=class2_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc1 extends  Association src=class2_namedst=class4_name src_multiplicity =src_mlpc2 dst_multiplicity =dst_mlpc} one sig assoc2 extends  Association src=class10_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc3 extends  Association src=class10_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc4 extends  Association src=class10_namedst=class6_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} one sig assoc5 extends  Association src=class6_namedst=class1_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} one sig assoc6 extends  Association src=class6_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc7 extends  Association src=class1_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc8 extends  Association src=class1_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc9 extends  Association src=class2_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} pred show run show ,MappingStrategyforclass1_name:map_str2MappingStrategyforclass10_name:map_str2MappingStrategyforclass5_name:map_str3MappingStrategyforclass7_name:map_str3MappingStrategyforclass8_name:map_str3AssociationStrategyforassoc2:assoc_str1AssociationStrategyforassoc6:assoc_str1AssociationStrategyforassoc1:assoc_str2AssociationStrategyforassoc3:assoc_str2AssociationStrategyforassoc4:assoc_str2AssociationStrategyforassoc5:assoc_str2AssociationStrategyforassoc7:assoc_str2AssociationStrategyforassoc9:assoc_str2,USEOM_name:0;CREATE TABLE `class7_name`(`c7_at1`c7_at1_type(64),`c2_at2`c2_at2_type(64),`c2_at1`c2_at1_typeNOT NULL, PRIMARY  KEY  (`c2_at1`)CREATE TABLE `class5_name`(c5_at1`c5_at1_type(64),`c2_at2`c2_at2_type(64),`c2_at1`c2_at1_typeNOT NULL, PRIMARY  KEY  (`c2_at1`)CREATE TABLE `assoc3`(c10_at1`c10_at1_type`c4_at3`c4_at3_typeNOT NULL,CREATE TABLE `class2_name ...
# ('module OM_name0 ;openDeclaration one sig class1_name extends ClassattrSet=c1_at1+c1_at2id=c1_at1noparentisAbstract=No} one sig c1_at1 extends c1_at1_type one sig c1_at2 extends c1_at2_type one sig class2_name extends ClassattrSet=c2_at1+c2_at2id=c2_at1noparentisAbstract=No} one sig c2_at1 extends c2_at1_type one sig c2_at1 extends c2_at2_type one sig class3_name extends ClassattrSet=c3_at1+c3_at2+c3_at3+c3_at4c3_at5+c3_at6id=c3_at1noparentisAbstract=No} one sig c3_at1 extends c3_at1_type one sig c3_at2 extends c3_at2_type one sig c3_at3 extends c3_at3_type one sig c3_at4 extends c3_at4_type one sig c3_at5 extends c3_at5_type one sig c3_at6 extends c3_at6_type one sig class4_name extends ClassattrSet=c4_at1+c4_at2+c4_at3+c4_at4id=c4_at3noparentisAbstract=No} one sig c4_at1 extends c4_at1_type one sig c4_at2 extends c4_at2_type one sig c4_at3 extends c4_at3_type one sig c4_at4 extends c4_at4_type one sig class5_name extends ClassattrSet=c5_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c5_at1 extends c5_at1_type one sig class6_name extends ClassattrSet=c6_at1_0+c6_at2+c6_at3+c6_at4id=c6_at2noparentisAbstract=No} one sig c6_at1_0 extends c6_at1_type one sig c6_at2 extends c6_at2_type one sig c6_at3 extends c6_at3_type one sig c6_at4 extends c6_at4_type one sig class7_name extends ClassattrSet=c7_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c7_at1 extends c7_at1_type one sig class8_name extends ClassattrSet=c8_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c8_at1 extends c8_at1_type one sig class9_name extends ClassattrSet=c9_at1 one parent  parentinclass2_nameid=c2_at1isAbstract=No} one sig c9_at1 extends c9_at1_type one sig class10_name extends ClassattrSet=c10_at1+c10_at2+c2_at2+c6_at3id=c10_at1noparentisAbstract=No} one sig c10_at1 extends c10_at1_type one sig c10_at2 extends c10_at2_type one sig assoc10 extends  Association src=class10_namedst=class2_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc1 extends  Association src=class2_namedst=class4_name src_multiplicity =src_mlpc2 dst_multiplicity =dst_mlpc} one sig assoc2 extends  Association src=class10_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc3 extends  Association src=class10_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc4 extends  Association src=class10_namedst=class6_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} one sig assoc5 extends  Association src=class6_namedst=class1_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} one sig assoc6 extends  Association src=class6_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc7 extends  Association src=class1_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc8 extends  Association src=class1_namedst=class4_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc9 extends  Association src=class2_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc2} pred show run show ,MappingStrategyforclass1_name:map_str2MappingStrategyforclass10_name:map_str2MappingStrategyforclass5_name:map_str3MappingStrategyforclass7_name:map_str3MappingStrategyforclass8_name:map_str3AssociationStrategyforassoc2:assoc_str1AssociationStrategyforassoc6:assoc_str1AssociationStrategyforassoc1:assoc_str2AssociationStrategyforassoc3:assoc_str2AssociationStrategyforassoc4:assoc_str2AssociationStrategyforassoc5:assoc_str2AssociationStrategyforassoc7:assoc_str2AssociationStrategyforassoc9:assoc_str2,USEOM_name:0;CREATE TABLE `class7_name`(`c7_at1`c7_at1_type(64),`c2_at2`c2_at2_type(64),`c2_at1`c2_at1_typeNOT NULL, PRIMARY  KEY  (`c2_at1`)CREATE TABLE `class5_name`(c5_at1`c5_at1_type(64),`c2_at2`c2_at2_type(64),`c2_at1`c2_at1_typeNOT NULL, PRIMARY  KEY  (`c2_at1`)CREATE TABLE `assoc3`(c10_at1`c10_at1_type`c4_at3`c4_at3_typeNOT NULL,CREATE TABLE `class2_name ...
# ('module OM_name: 0 openDeclaration one sig class1_name extends ClassattrSet=c1_at1+c1_at2id=c1_at1noparentisAbstract=No} one sig c1_at1 extends c1_at1_type one sig c1_at2 extends c1_at2_type one sig class2_name extends ClassattrSet=c2_at1+c2_at2id=c2_at1noparentisAbstract=No} one sig c2_at1 extends c2_at1_type one sig c2_at2 extends c2_at2_type one sig class3_name extends ClassattrSet=c3_at1+c3_at2id=c3_at1noparentisAbstract=No} one sig c3_at1 extends c3_at1_type one sig c3_at2 extends c3_at2_type one sig class4_name extends ClassattrSet=c4_at1+c4_at2+c4_at3+c4_at4id=c4_at1noparentisAbstract=No} one sig c4_at1 extends c4_at1_type one sig c4_at2 extends c4_at2_type one sig c4_at3 extends c4_at3_type one sig c4_at4 extends c4_at4_type one sig class5_name extends ClassattrSet=c5_at1+c5_at2 one parent  parentinclass4_nameid=c4_at1isAbstract=No} one sig c5_at1 extends c5_at1_type one sig c5_at2 extends c5_at2_type one sig class6_name extends ClassattrSet=c6_at1+c6_at2+c6_at3id=c6_at1noparentisAbstract=No} one sig c6_at1 extends c6_at1_type one sig c6_at2 extends c6_at2_type one sig c6_at3 extends c6_at3_type one sig assoc1 extends  Association src=class6_namedst=class4_name src_multiplicity =src_mlpc2 dst_multiplicity =dst_mlpc} one sig assoc2 extends  Association src=class1_namedst=class5_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc3 extends  Association src=class4_namedst=class1_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} one sig assoc4 extends  Association src=class3_namedst=class1_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc} pred show run show for30\u200b, Mapping Strategy of Tableclass4_name:map_str2 Mapping Strategy of Tableclass5_name:map_str2 Mapping Strategy of Tableclass7_name:map_str1 Mapping Strategy of Tableclass8_name:map_str1 Mapping Strategy of Tableclass10_name:map_str1AssociationStrategyforassoc4:assoc_type1AssociationStrategyforassoc1:assoc_type2AssociationStrategyforassoc2:assoc_type2AssociationStrategyforassoc3:assoc_type2AssociationStrategyforassoc4:assoc_type2,USEOM_name_0CREATE TABLE `assoc2`(`c7_at1`c7_at1_typeNOT NULL`c4_at1`c4_at1_typeNOT NULL KEY `FK_assoc2_c7_at1_idx`(`c7_at1`) KEY `FK_assoc2_c4_at1_idx`(`c4_at1`) PRIMARY  KEY  (`c7_at1`,`c4_at1`));CREATE TABLE `class2_name`(`c2_at2`c2_at2_type`c2_at1`c2_at1_typeNOT NULL PRIMARY  KEY  (`c2_at1`));CREATE TABLE `assoc5`(`c6_at1`c6_at1_typeNOT NULL`c1_at1`c1_at1_typeNOT NULL KEY `FK_assoc5_c6_at1_idx`(`c6_at1`), KEY `FK_assoc5_c1_at1_idx`(`c1_at1`), PRIMARY  KEY  (`c5_at1`,`c1_at1`));CREATE TABLE `class1_name`(`c1_at2`c1_at2_type`c1_at1`c1_at1_typeNOT NULL PRIMARY  KEY  (`c1_at1`));CREATE TABLE `class4_name`(`c4_at2`c4_at2_type`c4_at1`c4_at1_typeNOT NULL PRIMARY  KEY  (`c4_at1`));CREATE TABLE `class7_name`(`c7_at2`c7_at2_type(64)`c8_at2`c8_at2_type(64),`c8_at1`c8_at1_type(64),`c10_at1`c10_at1_type`c9_at1`c9_at1_type`c7_at1`c7_at1_typeNOT NULL PRIMARY  KEY  (`c7_at1`));CREATE TABLE `class6_name`(`c6_at2`c6_at2_type(64)`c6_at1`c6_at1_typeNOT NULL PRIMARY  KEY  (`c6_at1`));CREATE TABLE `class3_name`(`c3_at2`c3_at2_type(64)`c3_at1`c3_at1_typeNOT NULL`c2_at1`c2_at1_type KEY `FK_class3_name_c2_at1_idx`(`c2_at1`) PRIMARY  KEY  (`c3_at1`));CREATE TABLE `assoc4`(`c6_at1`c6_at1_typeNOT NULL`c2_at1`c2_at1_typeNOT NULL KEY `FK_assoc4_c6_at1_idx`(`c6_at1`) KEY `FK_assoc4_c2_at1_idx`(`c2_at1`) PRIMARY  KEY  (`c6_at1`,`c2_at1`));CREATE TABLE `assoc3`(`c7_at1`c7_at1_typeNOT NULL`c6_at1`c6_at1_typeNOT NULL KEY `FK_assoc3_c7_at1_idx`(`c7_at1`), KEY `FK_assoc3_c6_at1_idx`(`c6_at1`), PRIMARY  KEY  (`c7_at1`,`c6_at1`)); ALTER TABLE `assoc2` ADD CONSTRAINT `FK_assoc2_c7_at1` FOREIGN  KEY  (`c7_at1`) REFERENCES `class7_name`(`c7_at1`) ON DELETE CASCADE ON UPDATE CASCADE  ADD CONSTRAINT `FK_assoc2_c4_at1` FOREIGN  KEY  (`c4_at1`) REFERENCES `class4_name`(`c4_at1`) ON DELETE CASCADE ON UPDATE CASCADE  ALTER TABLE `class10_name` ADD CONSTRAINT `FK_assoc5_c6_at1` FOREIGN  KEY  (`c6_at1`) REFERENCES `class6_name`(`c6_at1`)  ...
# ('module OM_name: 0 ,openDeclaration one sig class1_name extends ClassattrSet=c1_at1id=c1_at1isAbstract=No no parent} one sig c1_at1 extends c1_at1_type, one sig class01_name extends ClassattrSet=c01_at1id=c01_at1isAbstract=No no parent} one sig c01_at1 extends c01_at1_type, one sig assoc1 extends  Association src=class1_namedst=class01_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc,} one sig class2_name extends ClassattrSet=c2_at1id=c2_at1isAbstract=No no parent} one sig c2_at1 extends c2_at1_type, one sig assoc2 extends  Association src=class1_namedst=class2_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc,} one sig class3_name extends ClassattrSet=c3_at1+c3_at2id=c3_at1isAbstract=No no parent} one sig c3_at1 extends c3_at1_type one sig c3_at2 extends c3_at2_type, one sig class4_name extends ClassattrSet=c4_at1 one parent id=c3_at1isAbstract=Noparentinclass3_name} one sig c4_at1 extends c4_at1_type, one sig assoc3 extends Associationdst=class2_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc,} one sig class5_name extends ClassattrSet=c5_at1+c5_at2 one parent id=c3_at1isAbstract=Noparentinclass3_name} one sig c5_at2 extends c5_at2_type one sig c5_at1 extends c5_at1_type one sig assoc4 extends  Association src=class01_namedst=class3_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc,} one sig class6_name extends ClassattrSet=c6_at1+c6_at2id=categoryIDisAbstract=No no parent} one sig c6_at1 extends c6_at1_type one sig c6_at2 extends c6_at2_type one sig class7_name extends ClassattrSet=c7_at1+c7_at2+c7_at3+c7_at4id=c7_at1isAbstract=No no parent} one sig c7_at1 extends c7_at1_type one sig c7_at2 extends c7_at2_type one sig c7_at3 extends c7_at3_type one sig c7_at4 extends c7_at4_type one sig assoc5 extends  Association src=class7_namesrc=class6_name src_multiplicity =src_mlpc2 dst_multiplicity =dst_mlpc,} one sig class8_name extends ClassattrSet=c8_at1id=c8_at1isAbstract=No no parent} one sig c8_at1 extends Integer one sig assoc6 extends  Association src=class7_namedst=class8_name src_multiplicity =src_mlpc dst_multiplicity =dst_mlpc,} one sig assoc7 extends  Association src=class7_namedst=class3_name src_multiplicity =src_mlpc2 dst_multiplicity =dst_mlpc,} one sig class9_name extends ClassattrSet=c9_at1+c10_at2 one parent id=c7_at1isAbstract=Noparentinclass7_name} one sig c9_at1 extends c9_at1_type one sig c10_at2 extends c10_at2_type one sig class10_name extends ClassattrSet=c10_at1 one parent id=c7_at1isAbstract=Noparentinclass7_name} one sig c10_at1 extends c10_at1_type one sig class11_name extends ClassattrSet=c11_at1 one parent id=c7_at1isAbstract=Noparentinclass7_name} one sig c11_at1 extends string one sig class12_name extends ClassattrSet=c12_at1+c12_at2+c12_at3id=c12_at1isAbstract=No no parent} one sig c12_at1 extends c12_at1_type one sig c12_at2 extends c12_at2_type one sig c12_at3 extends c12_at3_type one sig assoc8 extends  Association src=class7_namesrc=class12_name src_multiplicity =src_mlpc2 dst_multiplicity =dst_mlpc,} one sig class13_name extends ClassattrSet=c13_at1 one parent id=c12_at1isAbstract=Noparentinclass12_name} one sig c13_at1 extends c13_at1_type one sig class14_name extends ClassattrSet=c14_at1 one parent id=c12_at1isAbstract=Noparentinclass12_name} one sig c14_at1 extends c14_at1_type pred show run show ,TableName:class1_nameTableName:class01_nameTableNameclass2_nameTableNameclass3_nameTableNameclass4_nameTableNameclass5_nameTableNameassoc7TableNameassoc5TableNameclass8_nameMappingStrategyforclass1_name:map_str2MappingStrategyforclass6_name:map_str2MappingStrategyforclass7_name:map_str2MappingStrategyforclass11_name:map_str2MappingStrategyforclass12_name:map_str2MappingStrategyforclass4_name:map_str3MappingStrategyforclass3_name:map_str3MappingStrategyforclass9_name:map_str3MappingStrategyforclass10_name:map_str3MappingStrategyforclass11_name:map_str3MappingStrategyforclass14_name:map_str3AssociationStrategyforassoc1:assoc_str1AssociationStrate ...

# %% [markdown]
# Now, let's split the sentence pairs into a training set, a validation set,
# and a test set.

# %%
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples :]

print(f"{len(text_pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 26470 total pairs
# 18530 training pairs
# 3970 validation pairs
# 3970 test pairs

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use two instances of the `TextVectorization` layer to vectorize the text
# data (one for English and one for Spanish),
# that is to say, to turn the original strings into integer sequences
# where each integer represents the index of a word in a vocabulary.
#
# The English layer will use the default string standardization (strip punctuation characters)
# and splitting scheme (split on whitespace), while
# the Spanish layer will use a custom standardization, where we add the character
# `"¿"` to the set of punctuation characters to be stripped.
#
# Note: in a production-grade machine translation model, I would not recommend
# stripping the punctuation characters in either language. Instead, I would recommend turning
# each punctuation character into its own token,
# which you could achieve by providing a custom `split` function to the `TextVectorization` layer.

# %%
strip_chars = string.punctuation + ""
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

vocab_size = 15000
sequence_length = 500
batch_size = 64


def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


eng_vectorization = TextVectorization(
    max_tokens=vocab_size, output_mode="int", output_sequence_length=sequence_length,
)
spa_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_eng_texts = [pair[0] for pair in train_pairs]
train_spa_texts = [pair[1] for pair in train_pairs]
eng_vectorization.adapt(train_eng_texts)
spa_vectorization.adapt(train_spa_texts)

# %% [markdown]
# Next, we'll format our datasets.
#
# At each training step, the model will seek to predict target words N+1 (and beyond)
# using the source sentence and the target words 0 to N.
#
# As such, the training dataset will yield a tuple `(inputs, targets)`, where:
#
# - `inputs` is a dictionary with the keys `encoder_inputs` and `decoder_inputs`.
# `encoder_inputs` is the vectorized source sentence and `encoder_inputs` is the target sentence "so far",
# that is to say, the words 0 to N used to predict word N+1 (and beyond) in the target sentence.
# - `target` is the target sentence offset by one step:
# it provides the next words in the target sentence -- what the model will try to predict.

# %%
def format_dataset(eng, spa):
    eng = eng_vectorization(eng)
    spa = spa_vectorization(spa)
    return ({"encoder_inputs": eng, "decoder_inputs": spa[:, :-1],}, spa[:, 1:])


# def make_dataset(pairs):
#     eng_texts, spa_texts = zip(*pairs)
#     eng_texts = list(eng_texts)
#     spa_texts = list(spa_texts)
#     dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
#     dataset = dataset.batch(batch_size)
#     dataset = dataset.map(format_dataset)
#     return dataset.shuffle(2048).prefetch(16).cache()

def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)

    # Distribute the dataset creation across multiple GPUs
    if num_gpus > 1:
        dataset = dataset.distribute(strategy)

    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()

# Create the datasets
train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %% [markdown]
# Let's take a quick look at the sequence shapes
# (we have batches of 64 pairs, and all sequences are 20 steps long):

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs["encoder_inputs"].shape: (64, 500)
# inputs["decoder_inputs"].shape: (64, 500)
# targets.shape: (64, 500)

# %% [markdown]
# ## Building the model
#
# Our sequence-to-sequence Transformer consists of a `TransformerEncoder`
# and a `TransformerDecoder` chained together. To make the model aware of word order,
# we also use a `PositionalEmbedding` layer.
#
# The source sequence will be pass to the `TransformerEncoder`,
# which will produce a new representation of it.
# This new representation will then be passed
# to the `TransformerDecoder`, together with the target sequence so far (target words 0 to N).
# The `TransformerDecoder` will then seek to predict the next words in the target sequence (N+1 and beyond).
#
# A key detail that makes this possible is causal masking
# (see method `get_causal_attention_mask()` on the `TransformerDecoder`).
# The `TransformerDecoder` sees the entire sequences at once, and thus we must make
# sure that it only uses information from target tokens 0 to N when predicting token N+1
# (otherwise, it could use information from the future, which would
# result in a model that cannot be used at inference time).

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, mask=None):
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
        attention_output = self.attention(
            query=inputs, value=inputs, key=inputs, attention_mask=padding_mask
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "dense_dim": self.dense_dim,
            "num_heads": self.num_heads,
        })
        return config


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)
    def get_config(self):
        config = super().get_config()
        config.update({
            "sequence_length": self.sequence_length,
            "vocab_size": self.vocab_size,
            "embed_dim": self.embed_dim,
        })
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(latent_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "latent_dim": self.latent_dim,
            "num_heads": self.num_heads,
        })
        return config

# %% [markdown]
# Next, we assemble the end-to-end model.

# %%
embed_dim = 256
latent_dim = 2048
num_heads = 8


with strategy.scope():

  encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
  x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
  encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
  encoder = keras.Model(encoder_inputs, encoder_outputs)

  decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
  encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
  x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
  x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
  x = layers.Dropout(0.5)(x)
  decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
  decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs)

  decoder_outputs = decoder([decoder_inputs, encoder_outputs])
  transformer = keras.Model(
      [encoder_inputs, decoder_inputs], decoder_outputs, name="transformer"
  )

# %% [markdown]
# ## Training our model
#
# We'll use accuracy as a quick way to monitor training progress on the validation data.
# Note that machine translation typically uses BLEU scores as well as other metrics, rather than accuracy.
#
# Here we only train for 1 epoch, but to get the model to actually converge
# you should train for at least 30 epochs.

# %%
epochs = 120
  # This should be at least 30 for convergence
# steps_per_epoch = 100,
transformer.summary()
transformer.compile(
    "adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
history = transformer.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   3968000     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  model_1 (Functional)           (None, None, 15000)  13082520    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 20,205,976
# Trainable params: 20,205,976
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/120
# 290/290 [==============================] - 104s 274ms/step - loss: inf - accuracy: 0.8695 - val_loss: 0.0418 - val_accuracy: 0.9913
# Epoch 2/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0285 - accuracy: 0.9948 - val_loss: 0.0167 - val_accuracy: 0.9968
# Epoch 3/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0168 - accuracy: 0.9969 - val_loss: 0.0124 - val_accuracy: 0.9977
# Epoch 4/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0116 - accuracy: 0.9980 - val_loss: 0.0112 - val_accuracy: 0.9979
# Epoch 5/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.0096 - val_accuracy: 0.9985
# Epoch 6/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 0.0081 - val_accuracy: 0.9989
# Epoch 7/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.0077 - val_accuracy: 0.9989
# Epoch 8/120
# 290/290 [==============================] - 42s 146ms/step - loss: inf - accuracy: 0.1207 - val_loss: inf - val_accuracy: 0.0957
# Epoch 9/120
# 290/290 [==============================] - 42s 146ms/step - loss: inf - accuracy: 0.0935 - val_loss: inf - val_accuracy: 0.0957
# Epoch 10/120
# 290/290 [==============================] - 42s 146ms/step - loss: inf - accuracy: 0.2163 - val_loss: inf - val_accuracy: 0.4267
# Epoch 11/120
# 290/290 [==============================] - 42s 146ms/step - loss: inf - accuracy: 0.5947 - val_loss: 0.8885 - val_accuracy: 0.7355
# Epoch 12/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.7378 - accuracy: 0.7804 - val_loss: 0.4794 - val_accuracy: 0.8568
# Epoch 13/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.4829 - accuracy: 0.8523 - val_loss: 0.3656 - val_accuracy: 0.8782
# Epoch 14/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.3962 - accuracy: 0.8726 - val_loss: 0.3080 - val_accuracy: 0.8960
# Epoch 15/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.2929 - accuracy: 0.9009 - val_loss: 0.2574 - val_accuracy: 0.9079
# Epoch 16/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.3366 - accuracy: 0.8937 - val_loss: 0.2157 - val_accuracy: 0.9268
# Epoch 17/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.2543 - accuracy: 0.9191 - val_loss: 0.1693 - val_accuracy: 0.9414
# Epoch 18/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.1737 - accuracy: 0.9417 - val_loss: 0.1440 - val_accuracy: 0.9496
# Epoch 19/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.1432 - accuracy: 0.9512 - val_loss: 0.1222 - val_accuracy: 0.9573
# Epoch 20/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.1232 - accuracy: 0.9581 - val_loss: 0.1059 - val_accuracy: 0.9632
# Epoch 21/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.1701 - accuracy: 0.9479 - val_loss: 0.0994 - val_accuracy: 0.9663
# Epoch 22/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0981 - accuracy: 0.9677 - val_loss: 0.0827 - val_accuracy: 0.9726
# Epoch 23/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0867 - accuracy: 0.9714 - val_loss: 0.0724 - val_accuracy: 0.9761
# Epoch 24/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0802 - accuracy: 0.9735 - val_loss: 0.0681 - val_accuracy: 0.9778
# Epoch 25/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0726 - accuracy: 0.9760 - val_loss: 0.0649 - val_accuracy: 0.9786
# Epoch 26/120
# 290/290 [==============================] - 42s 146ms/step - loss: inf - accuracy: 0.9458 - val_loss: 0.0782 - val_accuracy: 0.9756
# Epoch 27/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0737 - accuracy: 0.9762 - val_loss: 0.0590 - val_accuracy: 0.9807
# Epoch 28/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0607 - accuracy: 0.9799 - val_loss: 0.0550 - val_accuracy: 0.9824
# Epoch 29/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0556 - accuracy: 0.9819 - val_loss: 0.0492 - val_accuracy: 0.9848
# Epoch 30/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0492 - accuracy: 0.9844 - val_loss: 0.0427 - val_accuracy: 0.9872
# Epoch 31/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0456 - accuracy: 0.9856 - val_loss: 0.0426 - val_accuracy: 0.9871
# Epoch 32/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0422 - accuracy: 0.9868 - val_loss: 0.0636 - val_accuracy: 0.9811
# Epoch 33/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.1128 - accuracy: 0.9700 - val_loss: 0.0425 - val_accuracy: 0.9875
# Epoch 34/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0405 - accuracy: 0.9875 - val_loss: 0.0378 - val_accuracy: 0.9892
# Epoch 35/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0364 - accuracy: 0.9888 - val_loss: 0.0358 - val_accuracy: 0.9899
# Epoch 36/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0344 - accuracy: 0.9895 - val_loss: 0.0353 - val_accuracy: 0.9900
# Epoch 37/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0493 - accuracy: 0.9859 - val_loss: 0.1769 - val_accuracy: 0.9525
# Epoch 38/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0516 - accuracy: 0.9842 - val_loss: 0.0356 - val_accuracy: 0.9899
# Epoch 39/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0311 - accuracy: 0.9904 - val_loss: 0.0338 - val_accuracy: 0.9906
# Epoch 40/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0294 - accuracy: 0.9910 - val_loss: 0.0539 - val_accuracy: 0.9843
# Epoch 41/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0297 - accuracy: 0.9909 - val_loss: 0.0321 - val_accuracy: 0.9915
# Epoch 42/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.0291 - val_accuracy: 0.9927
# Epoch 43/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0268 - accuracy: 0.9918 - val_loss: 0.0503 - val_accuracy: 0.9863
# Epoch 44/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0263 - accuracy: 0.9919 - val_loss: 0.0292 - val_accuracy: 0.9926
# Epoch 45/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.0280 - val_accuracy: 0.9933
# Epoch 46/120
# 290/290 [==============================] - 42s 146ms/step - loss: inf - accuracy: 0.9690 - val_loss: 0.0380 - val_accuracy: 0.9896
# Epoch 47/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0308 - accuracy: 0.9906 - val_loss: 0.0307 - val_accuracy: 0.9922
# Epoch 48/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.0285 - val_accuracy: 0.9929
# Epoch 49/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0232 - accuracy: 0.9929 - val_loss: 0.0284 - val_accuracy: 0.9932
# Epoch 50/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0365 - accuracy: 0.9894 - val_loss: 0.0384 - val_accuracy: 0.9899
# Epoch 51/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0269 - accuracy: 0.9920 - val_loss: 0.0274 - val_accuracy: 0.9934
# Epoch 52/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.0258 - val_accuracy: 0.9939
# Epoch 53/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.0258 - val_accuracy: 0.9942
# Epoch 54/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0214 - accuracy: 0.9935 - val_loss: 0.0256 - val_accuracy: 0.9942
# Epoch 55/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0259 - val_accuracy: 0.9939
# Epoch 56/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0336 - accuracy: 0.9903 - val_loss: 0.0241 - val_accuracy: 0.9945
# Epoch 57/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.0229 - val_accuracy: 0.9947
# Epoch 58/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0169 - accuracy: 0.9948 - val_loss: 0.0226 - val_accuracy: 0.9951
# Epoch 59/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0178 - accuracy: 0.9946 - val_loss: 0.0227 - val_accuracy: 0.9950
# Epoch 60/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0232 - val_accuracy: 0.9949
# Epoch 61/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0240 - val_accuracy: 0.9947
# Epoch 62/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0240 - val_accuracy: 0.9948
# Epoch 63/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0231 - val_accuracy: 0.9951
# Epoch 64/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0266 - val_accuracy: 0.9938
# Epoch 65/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0383 - accuracy: 0.9895 - val_loss: 0.0452 - val_accuracy: 0.9881
# Epoch 66/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0294 - accuracy: 0.9915 - val_loss: 0.0234 - val_accuracy: 0.9949
# Epoch 67/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.0222 - val_accuracy: 0.9955
# Epoch 68/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 0.0215 - val_accuracy: 0.9958
# Epoch 69/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.0223 - val_accuracy: 0.9956
# Epoch 70/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0221 - val_accuracy: 0.9958
# Epoch 71/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.0268 - val_accuracy: 0.9943
# Epoch 72/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0212 - val_accuracy: 0.9960
# Epoch 73/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.0207 - val_accuracy: 0.9960
# Epoch 74/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0266 - val_accuracy: 0.9944
# Epoch 75/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.0208 - val_accuracy: 0.9962
# Epoch 76/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0208 - val_accuracy: 0.9963
# Epoch 77/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0439 - accuracy: 0.9895 - val_loss: 0.0238 - val_accuracy: 0.9949
# Epoch 78/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0139 - accuracy: 0.9962 - val_loss: 0.0200 - val_accuracy: 0.9964
# Epoch 79/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.0194 - val_accuracy: 0.9966
# Epoch 80/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.0195 - val_accuracy: 0.9966
# Epoch 81/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.0304 - val_accuracy: 0.9936
# Epoch 82/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0195 - val_accuracy: 0.9966
# Epoch 83/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0197 - val_accuracy: 0.9967
# Epoch 84/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0191 - val_accuracy: 0.9968
# Epoch 85/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0197 - val_accuracy: 0.9966
# Epoch 86/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0225 - val_accuracy: 0.9959
# Epoch 87/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0197 - val_accuracy: 0.9967
# Epoch 88/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0271 - accuracy: 0.9931 - val_loss: 0.0222 - val_accuracy: 0.9955
# Epoch 89/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.0182 - val_accuracy: 0.9970
# Epoch 90/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0189 - val_accuracy: 0.9968
# Epoch 91/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.0189 - val_accuracy: 0.9970
# Epoch 92/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0187 - val_accuracy: 0.9970
# Epoch 93/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0094 - accuracy: 0.9975 - val_loss: 0.0183 - val_accuracy: 0.9971
# Epoch 94/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0186 - accuracy: 0.9951 - val_loss: 0.0189 - val_accuracy: 0.9969
# Epoch 95/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0188 - val_accuracy: 0.9971
# Epoch 96/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.0184 - val_accuracy: 0.9972
# Epoch 97/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.0180 - val_accuracy: 0.9974
# Epoch 98/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0189 - val_accuracy: 0.9971
# Epoch 99/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.0177 - val_accuracy: 0.9975
# Epoch 100/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0179 - val_accuracy: 0.9974
# Epoch 101/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0276 - val_accuracy: 0.9941
# Epoch 102/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0181 - val_accuracy: 0.9975
# Epoch 103/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.0176 - val_accuracy: 0.9975
# Epoch 104/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0179 - val_accuracy: 0.9974
# Epoch 105/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.0174 - val_accuracy: 0.9975
# Epoch 106/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0179 - val_accuracy: 0.9975
# Epoch 107/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0178 - accuracy: 0.9957 - val_loss: 0.0188 - val_accuracy: 0.9972
# Epoch 108/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.0171 - val_accuracy: 0.9978
# Epoch 109/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0180 - val_accuracy: 0.9976
# Epoch 110/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0172 - val_accuracy: 0.9978
# Epoch 111/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0176 - val_accuracy: 0.9977
# Epoch 112/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0182 - val_accuracy: 0.9975
# Epoch 113/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0178 - val_accuracy: 0.9978
# Epoch 114/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0176 - val_accuracy: 0.9978
# Epoch 115/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.0171 - val_accuracy: 0.9979
# Epoch 116/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0172 - val_accuracy: 0.9980
# Epoch 117/120
# 290/290 [==============================] - 42s 146ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0173 - val_accuracy: 0.9980
# Epoch 118/120
# 290/290 [==============================] - 43s 147ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0175 - val_accuracy: 0.9980
# Epoch 119/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0202 - val_accuracy: 0.9972
# Epoch 120/120
# 290/290 [==============================] - 42s 147ms/step - loss: 0.0100 - accuracy: 0.9975 - val_loss: 0.0172 - val_accuracy: 0.9980

# %%
import matplotlib.pyplot as plt


plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.legend()
plt.show()

# %% [markdown]
# ## Decoding test sentences
#
# Finally, let's demonstrate how to translate brand new English sentences.
# We simply feed into the model the vectorized English sentence
# as well as the target token `"[start]"`, then we repeatedly generated the next token, until
# we hit the token `"[end]"`.

# %%
spa_vocab = spa_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 500


def decode_sequence(input_sentence):
    tokenized_input_sentence = eng_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = spa_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence


test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(30):
    input_sentence = random.choice(test_eng_texts)
    translated = decode_sequence(input_sentence)

# %% [markdown]
# ## Adding data from Test set

# %%
import pandas as pd


dc = pd.read_excel('random_set_1.0.xlsx')

# %%
dc.head()
# Out:
#                                           OM_Regular  OM_Prediction
# 0  module OM_name: 0 ,openDeclaration one sig cla...              1
# 1  module OM_name: 0 ,openDeclaration one sig cla...              1
# 2  module OM_name: 0 ,openDeclaration one sig cla...              1
# 3  module OM_name: 0 ,openDeclaration one sig cla...              1
# 4  module OM_name: 0 ,openDeclaration one sig cla...              0

# %%
X_test2 = dc['OM_Regular'].values
y_test2 = dc['OM_Prediction'].values

# %%
print(X_test2.shape)
print(y_test2.shape)

print("X data type: ", X_test2.dtype)
print("y data type: ", y_test2.dtype)
# Out:
# (4669,)
# (4669,)
# X data type:  object
# y data type:  int64

# %%
print(y_test2)
# Out:
# [1 1 1 ... 0 0 0]

# %%
inputs = X_test2

# %% [markdown]
# ## Output from Unseen Data

# %%
import time

start_time = time.time()
mylist_res = []
for sentence in inputs:
    result = decode_sequence(sentence)
    mylist_res.append(result)
    print(result)
    time.sleep(1)  # Add a 1-second delay between each print statement

end_time = time.time()
execution_time = end_time - start_time

print(f"Execution time: {execution_time} seconds")
print(mylist_res)
# Out:
# [start] module module omname opendeclaration one sig class1name extends c1at1type one sig c1at1 extends c1at1type one sig class1name one sig class2name extends c1at1type one parent one sig c2at1 extends c2at1type one sig class2namec7at1c7at1type64c2at2c2at2type64c2at1c2at1typenot c2at1type one sig c6at2type one sig class attrset c5at1c3at1 idc12at1isabstractnoparentinclass12name one fkassoc2c7at1idxc7at1 attrset c6at2 extends c3at4type one parent sig c6at2type one sig assoc2 extends c3at4type one sig assoc1 extends c4at2type one parent one sig assoc2 extends c4at2type one sig class4name extends c3at4type one sig c4at1 extends c4at1type one sig c4at1 c4at2type one parent parent one sig c4at1 extends c4at1type one sig assoc3 extends c6at3 extends c6at2type one fkassoc2c7at1idxc7at1 pred c6at2 extends c5at1type one sig class8name dstmlpc2 one sig assoc3 extends assoc3 extends cascadealter srcmultiplicity c6at4type add assoc4 extends c6at1type one sig assoc1 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show assoc2c4at3c4at3typenot strategy c8at2type pred show run show constraint show 4ncrfprocessstaff pred show class4namec4at2c4at2typec4at1c4at1typenot dstmlpc2 one fkassoc2c7at1idxc7at1 key fkassoc2c7at1idxc7at1 key c2at1create srcmlpc dstmultiplicity dstmlpc one sig class7name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 dstmlpc2 one fkassoc2c7at1idxc7at1 key fkassoc2c7at1idxc7at1 key c2at1create table class2namec2at2c2at2typec5at1c5at1typec2at1c2at1typenot dstmlpc2 pred class4namec4at2c4at2typec4at1c4at1typenot dstmlpc2 one sig c3at4 srcmultiplicity srcmlpc dstmultiplicity 1taticardmaker assoc9 srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig run show run show fkclass2namec5at1idx c2at2type64c6at10 association srcclass6namedstcustomer srcmultiplicity srcclass3namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 dstmlpc2 one sig c5at1key tableclass1namemapstr1 mapping run show fkclass3namec6at1 nullc2at1c2at1type key fkclass1namec3at1idxc3at1 primary key c1at1create extends on delete cascade on delete cascade nullcreate table c5at1c3at1create table fkassoc4c3at1idxc3at1 primary key c1at1create table class1namec1at2c4at2type64c3at1c3at2typec1at1c1at1type pred fkassoc3c6at1idxc6at1 primary key fkassoc5c2at1idxc2at1 key fkassoc5c2at1idxc2at1 onesigclass7nameextendsclassattrsetc7at1oneparentparentinclass5nameidc3at1isabstractnoonesigc7at1extendsc7at1type key c6at1 on update cascade on delete cascade ​p [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c3at1c3at2typec1at1c1at1type key fkclass1namec3at1idxc3at1 primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table assoc4c5at1c5at1typenot nullc3at1c3at2type key fkassoc4c5at1idxc5at1 key fkassoc4c3at1idxc3at1 primary key c5at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class1name add constraint fkclass1namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table assoc4 add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type key fkclass5namec3at1idxc3at1 primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c1at1c1at1type primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table assoc5c3at1c3at2typec1at1c1at1type key fkassoc5c3at1idxc3at1 key fkassoc5c1at1idxc1at1 primary key c3at1c1at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class5name add constraint fkclass5namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc5 add constraint fkassoc5c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade add constraint fkassoc5c1at1 foreign key c1at1 references class1namec1at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c4at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade [end]
# [start] np module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig class3name extends c3at4type one sig c3at4 extends c3at4type one sig c3at5 extends classattrsetc4at1c4at2idc4at1noparentisabstractno sig c4at1 extends c4at1type one sig c4at1 extends c3at4type one sig class4name extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig c6at3 extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c4at1type one sig c6at2 extends c6at1type pred c5at4 extends c6at1type srcmultiplicity srcmlpc2 dstmultiplicity extends association association classattrsetc7at1 one sig assoc1 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc2 srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig srcclass3namedstclass4name parent one sig c6at1 extends association assoc5 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig c4at1primary primary key c6at10c4at1association strategy idc6at1 c6at2 extends cascadealter table c5at1key fkassoc4c3at1idx for30​ mapping nullc1at1c1at1typenot nullc1at1c1at1type key c3at1c1at1create table nullc3at1 c3at1typec2at1 c2at1typeprimary key c3at1c1at1create table c3at1key primary key c3at1c1at1create table parent one parent one sig assoc3 null primary key c5at1create table nullc3at1 c3at1typec2at1 c6at10primary key c5at1add c6at2 extends association srcclass3namedstclass4name dstmlpc2 pred show fkclass3namec6at1 foreign key idc7at1isabstractnoparentinclass7name one fkassoc2c3at1idxc3at1 srcmultiplicity srcmlpc primary key fkassoc2c3at1idxc3at1 primary key fkassoc9c1at1idxc1at1 primary key c1at1 on delete cascade on delete cascade on delete cascade on foreign key c1at1 on delete cascade on delete cascade on delete cascade on delete cascade on update cascade mapping nullc1at1c1at1typenot nullc1at1c1at1type key fkassoc2c3at1idxc3at1 table assoc4c5at1c5at1typenot c6at1 alter table fkassoc4c3at1idxc3at1 primary key c4at1create table c4at1 on delete cascade on update cascade alter table assoc4 add constraint class6namec6at2 on delete cascade alter table c4at1 on delete cascade on update cascade alter table fkassoc4c3at1idxc3at1 primary key c4at1create table c5at1 [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c3at1c3at2typec1at1c1at1type key fkclass1namec3at1idxc3at1 primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table assoc4c5at1c5at1typenot nullc3at1c3at2type key fkassoc4c5at1idxc5at1 key fkassoc4c3at1idxc3at1 primary key c5at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class1name add constraint fkclass1namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table assoc4 add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc3c4at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade alter table assoc2 [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c3at1c3at2typec1at1c1at1type key fkclass1namec3at1idxc3at1 primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table assoc4c5at1c5at1typenot nullc3at1c3at2type key fkassoc4c5at1idxc5at1 key fkassoc4c3at1idxc3at1 primary key c5at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class1name add constraint fkclass1namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table assoc4 add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc3c4at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade alter table assoc2 [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c3at1c3at2typec1at1c1at1type key fkclass1namec3at1idxc3at1 primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table assoc4c5at1c5at1typenot nullc3at1c3at2type key fkassoc4c5at1idxc5at1 key fkassoc4c3at1idxc3at1 primary key c5at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class1name add constraint fkclass1namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table assoc4 add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade [end]
# [start] module module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c3at1c3at2typec1at1c1at1type key fkclass1namec3at1idxc3at1 primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table assoc4c5at1c5at1typenot nullc3at1c3at2type key fkassoc4c5at1idxc5at1 key fkassoc4c3at1idxc3at1 primary key c5at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class1name add constraint fkclass1namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table assoc4 add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c3at1c3at2typec1at1c1at1type key fkclass1namec3at1idxc3at1 primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table assoc4c5at1c5at1typenot nullc3at1c3at2type key fkassoc4c5at1idxc5at1 key fkassoc4c3at1idxc3at1 primary key c5at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class1name add constraint fkclass1namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table assoc4 add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade add constraint fkassoc4c5at1 foreign key c5at1 references class5namec5at1 on delete cascade on update cascade [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type key fkclass5namec3at1idxc3at1 primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c1at1c1at1type primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table assoc5c3at1c3at2typec1at1c1at1type key fkassoc5c3at1idxc3at1 key fkassoc5c1at1idxc1at1 primary key c3at1c1at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class5name add constraint fkclass5namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc5 add constraint fkassoc5c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade add constraint fkassoc5c1at1 foreign key c1at1 references class1namec1at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c4at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade [end]
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig class3name extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends classattrsetc4at1c4at2idc4at1noparentisabstractno sig c4at1 extends c4at1type one sig c4at1 extends c3at4type one sig class4name extends c4at1type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig c6at3 extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c4at1type one sig c6at2 extends c6at1type one sig 2nctcreditcard extends c6at3type one sig c6at3 extends c4at1type one parent parentinclass5nameidc3at1isabstractno one sig srcclass6namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig c6at4 extends srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table nullc3at1 c3at1type one sig assoc2 assocstr1association srcclass3namedstclass4name dstmlpc one sig assoc3 extends references fkassoc1c6at10idx srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc6 extends association fkassoc4c3at1idx c3at1primary key fkclass3namec10at1idxc10at1 key c3at1create table class3name c5at1type pred cascade c4at1type one fkclass5namec3at1idxc3at1 primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot assocstr1association srcclass3namedstclass4name dstmlpc2 pred show ​... table assoc3c4at1c4at1typenot c10at1type pred show ​... table class1name c4at2 c4at2type64c4at1 c4at1type one class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type key c7at1create table class5name null primary key fkclass1namec3at1idxc3at1 primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key c1at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key fkassoc3c4at1idxc4at1 key c1at1 table assoc2 add constraint fkclass3namec6at1 foreign key fkassoc3c4at1idxc4at1 key c5at1 c3at1 references class8namec8at1 assocstr2association nullc6at1c6at1typenot assocstr2use update cascadealter table class4name c4at2 null key fkassoc1c5at1idxc5at1 key fkclass4namec6at1idxc6at1 primary key c4at1create table class10namec10at2c10at2type64c2at2c2at2type64c10at1c10at1type key fkassoc3c4at1idxc4at1 key c3at1create table class8namec8at2c8at2type64c6at3c6at3type64c2at2c2at2type64c8at1c8at1typenot c4at1type not class1namec1at2c1at2type64c1at1c1at1type key fkassoc2c6at1idxc6at1 add constraint fkassoc6c1at1 foreign key fkclass4namec6at1idxc6at1 primary key fkassoc3c4at1idxc4at1 key c6at1 references class6namec6at1 on delete cascade on update cascadealter table class1namec1at2c1at2type64c1at1c1at1type primary key c5at1c3at1create table class1namec1at2c1at2type64c1at1c1at1type table class1namec1at2c1at2type64c1at1c1at1type key fkassoc2c5at1idxc5at1 key c5at1c2at1create table class1namec1at2c1at2type64c1at1c1at1type primary key fkassoc2c5at1idxc5at1 key c5at1c2at1create table assoc2c6at1c6at1typenot c10at1type null primary assocstr2c3at1 c5at2type null primary key c8at1 c6at1type null primary key c8at1 references class6namec6at1 on  ...
# [start] npmodule omname moduleomnameopendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig class1name extends c1at2type one sig class1name one sig c1at1 extends c1at2type sig class2name extends classattrsetc2at1 one sig assoc1 extends c2at1type one sig assoc1 extends classattrsetc3at1c3at2c3at3c3at4idc3at1noparentisabstractno one sig class3name dstmlpc one sig class4name extends c3at1type one sig c3at5 extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig class4name extends classattrsetc4at1c4at2c4at3c4at4idc4at1noparentisabstractno mapping c6at2type one sig assoc1 extends c6at2type one sig class2nameadd class5namec5at1c5at1typenot  2nctcardmaker 0anvcustomer extends 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker not 2nctcardmaker 2nctcardmaker 1taticardmaker key 2nctcardmaker 2nctcardmaker extends c7at1typec5at1 delete 2nctcardmaker 2nctcardmaker srcmultiplicity extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker srcmlpc2 2nctcardmaker 2nctcardmaker 2nctcardmaker delete 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker extends 2nctcardmaker 2nctcardmaker constraint 2nctcardmaker srcmultiplicity extends 2nctcardmaker 8eqclasses 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker c14at1type 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker extends 2nctcardmaker extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker extends 2nctcardmaker srcmlpc2 2nctcardmaker extends delete 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker c5at1 assoc4c3at1c3at1typenot extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker extends extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker srcmultiplicity 2nctcardmaker 2nctcardmaker delete 2nctcardmaker 2nctcardmaker extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo extends 2nctcardmaker 2nctcardmaker 2nctcardmaker extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo extends 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker delete 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker delete 2nctcardmaker 2nctcardmaker table 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker extends table 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker dst 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo delete 2nctcardmaker 2nctcardmaker 2nctcardmaker 1ncrfcreditcardinfo 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker delete 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker c6at1type 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker srcmlpc2 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2nctcardmaker 2 ...
# [start] p module omname 0 opendeclaration one sig class1name extends classattrsetc1at1c1at2idc1at1noparentisabstractno one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1 one parent parentinclass5nameidc3at1isabstractno one sig c2at1 extends c2at1type one sig class3name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at1 extends c3at1type one sig c3at3 extends c3at3type one sig c3at4 extends c3at4type one sig c3at5 extends c3at5type one sig class4name extends classattrsetc4at1c4at2idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig class5name extends classattrsetc5at1c3at1idc5at1noparentisabstractno one sig c5at1 extends c5at1type one sig class6name extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c6at1 extends c6at1type one sig c6at2 extends c6at2type one sig c6at3 extends c6at3type one sig class7name extends classattrsetc7at1 one parent parentinclass5nameidc3at1isabstractno one sig c7at1 extends c7at1type one sig assoc1 extends association srcclass6namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc2 extends association srcclass6namedstcustomer srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends association srcclass3namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc4 extends association srcclass3namedstclass5name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc3 extends associationsrcclass3namedstclass1name srcmultiplicity srcmlpc dstmultiplicity dstmlpc pred show run show ​... table class5namec5at1c5at1typenot nullc3at1c3at2type key fkclass5namec3at1idxc3at1 primary key c5at1create table class2namec7at1c7at1typec5at1c5at1typec3at1c3at2type primary key c3at1create table class6namec6at3c6at3type64c6at2c6at2type64c6at1c6at1typenot null primary key c6at1create table class1namec1at2c4at2type64c1at1c1at1type primary key c1at1create table class3namec3at3c3at3type64c3at2c3at2type64c6at1c6at1typec3at5c3at5typec3at4c3at4typec3at1c3at2type key fkclass3namec6at1idxc6at1 primary key c3at1create table assoc5c3at1c3at2typec1at1c1at1type key fkassoc5c3at1idxc3at1 key fkassoc5c1at1idxc1at1 primary key c3at1c1at1create table class4namec4at2c4at2type64c6at1c6at1typec4at1c4at1typenot null key fkclass4namec6at1idxc6at1 primary key c4at1create table assoc3c4at1c4at1typenot nullc3at1c3at2type key fkassoc3c4at1idxc4at1 key fkassoc3c3at1idxc3at1 primary key c4at1c3at1create table class8namec5at1c5at1typec3at1c3at2typec2at1c2at1type primary key c3at1 alter table class5name add constraint fkclass5namec3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade alter table class3name add constraint fkclass3namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc5 add constraint fkassoc5c3at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade add constraint fkassoc5c1at1 foreign key c1at1 references class1namec1at1 on delete cascade on update cascade alter table class4name add constraint fkclass4namec6at1 foreign key c6at1 references class6namec6at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc3c4at1 foreign key c4at1 references class4namec4at1 on delete cascade on update cascade add constraint fkassoc3c4at1 foreign key c3at1 references class3namec3at1 on delete cascade on update cascade [end]
# ...
# [start] np module omname 0 opendeclaration one sig class1name extends opendeclaration one sig c1at1 extends opendeclaration one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1c2at2idc2at1noparentisabstractno one sig c2at1 extends c2at1type one sig c2at2 extends c2at2type one sig class3name extends classattrsetc3at1c3at2idc3at1noparentisabstractno one sig c3at1 extends c3at1type one sig c3at2 extends c3at2type one sig class4name extends classattrsetc4at1c4at2c4at3c4at4idc4at1noparentisabstractno one sig c4at1 extends c4at1type one sig c4at2 extends c4at2type one sig c4at3 extends c4at3type one sig c4at4 extends c4at4type one sig class5name extends classattrsetc5at1c5at2 one parent parentinclass4nameidc4at1isabstractno one sig c5at1 extends c5at1type one sig c5at2 extends c5at2type one sig class6name extends c5at2 extends classattrsetc6at1c6at2c6at3idc6at1noparentisabstractno one sig c10at2 extends classattrsetc5at1c5at2 one sig c6at10 one sig c5at2 extends c6at3type one sig c4at1 nullcreate table class3namec8at1c8at1typec3at6c3at6typec3at5c3at5typec3at4c3at4typec3at3c3at3typec3at2c3at2typec3at1c3at1typenot table assoc8 extends c4at1type one sig c9at1 extends association c10at2type pred c5at4 one sig assoc4 extends c6at4type extends association classattrsetc10at1c10at2c2at2c6at3idc10at1noparentisabstractno one sig c6at2 one sig class8namec8at1c8at1type64c2at2c2at2type64c2at1c2at1typenot extends association c7at3type one sig c10at2 extends on constraint c9at1 extends classattrsetc6at1c6at2idcategoryidisabstractno c3at1type one sig nullc01at1c01at1typenot one sig assoc1 nullc1at1c1at1type key c12at1create extends references class2namec2at2c2at2type64c10at1c10at1typec2at1c2at1typenot null primary key fkclass2namec10at1idxc10at1 key idc7at1isabstractnoparentinclass7name one sig class8namec8at1c8at1typenot nullc7at1c7at1type key idc7at1isabstractnoparentinclass7name one sig assoc5 add srcclass7namesrcclass6name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig srcclass6namedstclass4name srcmultiplicity srcmlpc2 dstmultiplicity dstmlpc one sig assoc5 extends alter table assoc3 c4at2 srcmultiplicity foreign key idc3at1isabstractnoparentinclass3name one idc7at1isabstractnoparentinclass7name one sig c6at3 one parent idc7at1isabstractnoparentinclass7name one sig assoc7 add constraint run class11name extends c14at1type not class3name c3at3 extends srcclass2namedstclass4name srcmultiplicity srcmlpc2 one sig assoc7 null primary key idc7at1isabstractnoparentinclass7name one parent one parent one sig assoc3 dstmlpc2 pred of class7name null primary key idc7at1isabstractnoparentinclass7name one sig ... primary key c7at1 references assoc6c6at2c6at2typenot srcclass6namedstclass1name table assoc3 parentinclass2nameidc2at1isabstractno key c5at1create table class10namec10at2c10at2type64c10at1c10at1type primary key class3name add constraint fkassoc9c4at3 nullc6at2c6at2typenot on delete cascade on delete cascade add srcmlpc2 key fkassoc5c8at1idxc8at1 key c4at3c1at1create table class10namec10at2c10at2type64c6at3c6at3type64c2at2c2at2type64c10at1c10at1type key fkclass5namec2at1idxc2at1 key idc7at1isabstractnoparentinclass7name pred fkassoc1c4at3 foreign key idc7at1isabstractnoparentinclass7name one parent c3at4 add constraint fkassoc1c2at1 foreign key c3at1c2at1create table assoc2c6at1c6at1typenot references class4namec4at4c4at4type64c4at2c4at2type64c4at1c4at1type64c4at3c4at3typenot add constraint fkassoc4c10at1 nullc6at2c6at2typenot nullc1at1c1at1type on delete cascade on delete cascade on update cascade alter table srcmlpc2 key class3name add constraint fkclass8namec7at1 foreign key c2at1 references class2namec2at1 on delete cascade on update cascade alter table class10namec10at2c10at2type64c10at1c10at1type primary key c2at1 references class2namec2at1 on update cascade alter table assoc2 add constraint fkassoc4c6at2 foreign key c6at2 references class6namec6at2 on delete cascade on update cascade alter table assoc2 add cons ...
# [start] np module omname 0 opendeclaration one sig class1name extends opendeclaration one sig c1at1 extends opendeclaration one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1c2at2idc2at1noparentisabstractno one sig c2at1 extends c2at1type one sig c3at1type one sig class2name extends c2at4type extends c3at1type one sig c2at2 extends c3at1type one sig c3at2 extends c3at2type one sig class4name extends classattrsetc3at1c3at2idc3at1noparentisabstractno extends classattrsetc4at1c4at2c4at3c4at4idc4at3noparentisabstractno extends c3at2type one sig class8name extends class7name extends classattrsetc3at1c3at2idc3at1isabstractno mapping c4at2 extends c6at2type one sig c4at4 extends c4at4type one parent one parent one sig c4at2 extends c4at2type one sig c4at3 extends c4at3type one sig assoc3 extends c6at3 one sig class5name extends classattrsetc5at1 one parent one sig c4at1 extends c4at1type extends c6at1type one sig assoc4 extends c6at2 c3at6type one sig class8name extends c4at1type one parent one sig assoc10 extends association srcclass01namedstclass3name sig assoc10 extends association c6at2type one sig class7name extends classattrsetc7at1 pred assoc1 extends association c6at2type one sig assoc7 extends association assoc6 extends assoc4 extends association c8at1 extends c8at1type one sig c8at2type one sig assoc6 extends classattrsetc3at1c3at2idc3at1isabstractno pred class7name extends classattrsetc12at1c12at2c12at3idc12at1isabstractno one parent sig assoc6 null primary key c4at1create table class3name references class2namec2at3c2at3type64c2at2c2at2type64c2at4c2at4typec2at1c2at1type dstmultiplicity classattrsetc5at1 primary key idc7at1isabstractnoparentinclass7name one c6at1 c3at4type one fkassoc2c2at1idxc2at1 primary key c4at3c1at1create table class1namec1at1 on update cascade alter table class7name null primary key idc7at1isabstractnoparentinclass7name one c4at3c1at1create fkassoc5c1at1idx srcmlpc2 primary key idc12at1isabstractnoparentinclass12name idc12at1isabstractnoparentinclass12name one idc12at1isabstractnoparentinclass12name no fkassoc5c8at1idxc8at1 key idc12at1isabstractnoparentinclass12name idc12at1isabstractnoparentinclass12name [end]
# [start] np module omname 0 opendeclaration one sig class1name extends opendeclaration one sig c1at1 extends c1at1type one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1c2at2idc2at1noparentisabstractno one sig c2at1 extends c2at1type one sig c3at1type one sig class2name extends c2at4type extends c3at1type one sig c2at2 extends c3at1type one sig c3at2 extends c3at2type one sig class4name extends classattrsetc3at1c3at2idc3at1noparentisabstractno extends classattrsetc4at1c4at2c4at3c4at4idc4at3noparentisabstractno extends c3at2type one sig class8name extends class7name extends classattrsetc3at1c3at2idc3at1isabstractno mapping c4at2 extends c4at2type primary key c8at1 one sig c3at2 null primary key c8at1 extends classattrsetc5at1 pred show delete cascade on update cascade add class7name nullc3at1c3at1typenot null primary key sig srcclass10namedstclass3name nullc6at2c6at2typenot null key fkassoc1c3at1idxc3at1 key c8at1 alter table assoc2 c4at2 null primary key idc7at1isabstractnoparentinclass7name one c8at1 on update cascade add constraint fkassoc1c8at1 fkclass3namec8at1 foreign key c8at1 references table srcmlpc2 references class8namec8at1 key c8at1 references class8namec8at1 on references class8namec8at1 key c8at1 on delete cascade add constraint foreign key c8at1 on references class8namec8at1 add constraint fkassoc4c10at1 foreign key c6at1 dstmlpc 0 association srcmlpc 0 srcmlpc2 dstmultiplicity dstmlpc primary key c4at3 classattrsetc7at1 primary key fkassoc3c3at1idxc3at1 opendeclaration c4at3c1at1create class3namec3at3c3at3type64c3at2c3at2type64c3at4c3at4typec3at1c3at1typenot add constraint fkclass3namec6at10 foreign key c1at1 classattrsetc6at1c6at2idcategoryidisabstractno c3at2type one c4at1create table class5name add constraint assoc7 add constraint fkassoc4c6at2 nullc1at1int key c8at1 references fkassoc2c2at1 foreign key c8at1 on classattrsetc6at1c6at2idcategoryidisabstractno association srcclass6namedstclass1name table fkassoc3c4at1 foreign key c10at1 add constraint fkclass5namec2at1 cascade alter table assoc7 add constraint fkclass3namec6at10 foreign key c4at1 on delete cascade alter table c8at1 references class6namec6at2 key class4name add constraint fkassoc4c6at2 foreign key c7at1 add constraint fkassoc4c6at2 foreign key idc7at1isabstractnoparentinclass7name pred fkassoc1c8at1 references fkassoc5c7at1idxc7at1 primary key c4at1 srcmlpc idc12at1isabstractnoparentinclass12name fkassoc3c3at1idxc3at1 key c3at1 alter table srcmlpc2 idc12at1isabstractnoparentinclass12name one fkclass7namec2at1idxc2at1 c1at1type idc12at1isabstractnoparentinclass12name [end]
# [start] p module module 0 opendeclaration one sig class1name extends opendeclaration one sig class1name extends opendeclaration one sig c1at2 extends c1at2type one sig class2name extends classattrsetc2at1c2at2idc2at1noparentisabstractno one sig c2at1 extends c2at1type one sig c3at1type one sig class2name extends classattrsetc3at1c3at2c3at3c3at4c3at5idc3at1noparentisabstractno one sig c1at1 extends c3at1type one sig c3at1 extends c3at1type one sig c2at1type one sig class4name extends c3at1type one sig class6name extends c5at2type one sig c2at1type one sig class6name extends c3at6type one sig class6name extends classattrsetc4at1c4at2c4at3c4at4idc4at3noparentisabstractno one sig c5at2 extends c4at4type one sig c4at2 extends c3at1type one sig c3at2 extends c4at1 extends c4at1type one sig assoc3 one sig class5name extends c4at1type one parent one sig c4at1 extends c4at2type one sig class5name extends c10at1type one sig classattrsetc8at1c8at2c2at2c6at3idc8at1noparentisabstractno idc3at1isabstractnoparentinclass3name one sig c4at1 extends c7at1type one sig c4at1 extends c4at1type one sig c8at2type one sig class6name extends classattrsetc6at1c6at2idcategoryidisabstractno c3at4type one sig assoc6 extends c4at1type one sig assoc1 parent one sig assoc1 extends association srcclass8namedstclass4name parent one parent one sig class5name extends c7at1type one sig assoc7 extends c5at2type one sig srcclass10namedstclass3name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig c8at1 dstmlpc one sig class10name one sig c6at2 extends c10at1type one sig c10at2 extends c10at2type one sig assoc10 extends association show assoc7 extends association srcclass8namedstclass4name srcmultiplicity srcmlpc dstmultiplicity dstmlpc one sig assoc5 extends association srcclass8namedstclass6name srcmultiplicity srcmlpc dstmultiplicity dstmlpc2 pred show assoc7 key fkassoc2c4at3idxc4at3 primary key fkassoc2c2at1idxc2at1 primary key fkassoc2c2at1idxc2at1 primary key c4at3c2at1create table assoc1c01at1c01at1typenot nullc1at1c1at1typenot nullcreate table class3namec8at1c8at1typec3at6c3at6typec3at5c3at5typec3at4c3at4typec3at3c3at3typec3at2c3at2typec3at1c3at1typenot null key c4at3c2at1create table assoc10c3at1c3at1typenot nullc1at1c1at1typenot extends references assoc3c8at1c8at1typenot nullc3at1c3at1typenot nullcreate table class7namec7at1c7at1type64c2at1c2at1typenot nullc1at1c1at1type c3at2type one sig run show show show fkclass4namec6at2idxc6at2 primary key c4at3create table assoc7c6at2c6at2typenot srcclass2namedstclass4name srcmultiplicity foreign key c8at1 references assoc1c8at1c8at1typenot nullc2at1c2at1typenot on update cascade null key fkassoc2c2at1idxc2at1 primary key fkassoc2c2at1idxc2at1 primary key c4at3 on ... c6at10 add constraint fkclass3namec1at1 foreign key c4at3 alter table assoc7c6at2c6at2typenot srcclass2namedstclass4name nullc6at2c6at2typenot on update cascade add constraint fkassoc6c6at2 foreign key c1at1 references class1namec1at1 on delete cascade on update cascade add constraint fkassoc6c1at1 foreign key c1at1 on delete cascade alter key c8at1 references class1namec1at1 on update cascade add update cascade add constraint fkassoc5c8at1 foreign key c8at1 on delete cascade add constraint fkassoc6c1at1 foreign key c1at1 references class1namec1at1 on delete cascade on update cascade add constraint fkassoc6c1at1 foreign key c1at1 references class1namec1at1 on delete cascade alter table assoc1 srcmlpc pred show show fkclass3namec6at10 foreign key c6at2 references class4namec4at3 on delete cascade on update cascade add constraint fkassoc6c1at1 foreign key c1at1 references class1namec1at1 on delete cascade on update cascade alter table assoc1 add constraint fkassoc1c8at1 foreign key c8at1 references class8namec8at1 on delete cascade on update cascade alter table assoc3 add constraint fkassoc7c7at1 foreign key c6at2 references fkassoc5c6at2 foreign key c6at2 references class13name add constraint fkassoc1c8at1 foreign key c6at2 references class3namec3 ...

# %% [markdown]
# ## Result Computation

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve, classification_report

# %%
dd = pd.read_excel('random_set_1.0_pred.xlsx')

# %%
X_test_pred2 = dd['OM_Regular'].values
y_test_pred2 = dd['OM_Prediction'].values

# %%
print (y_test_pred2 )
# Out:
# [1 1 0 ... 0 0 0]

# %%
precision = precision_score(y_test2, y_test_pred2)
print("Testing: Precision = %f" % precision)


recall = recall_score(y_test2, y_test_pred2)
print("Testing: Recall = %f" % recall)


f1 = f1_score(y_test2, y_test_pred2)
print("Testing: F1 Score = %f" % f1)

print("\nConfusion Matrix (Test Data):\n", confusion_matrix(y_test2, y_test_pred2))
# Out:
# Testing: Precision = 0.313841
# Testing: Recall = 0.836910
# Testing: F1 Score = 0.456496
#
# Confusion Matrix (Test Data):
#  [[2691 1279]
#  [ 114  585]]

# %%
print(classification_report(y_test2,y_test_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.68      0.79      3970
#            1       0.31      0.84      0.46       699
#
#     accuracy                           0.70      4669
#    macro avg       0.64      0.76      0.63      4669
# weighted avg       0.86      0.70      0.74      4669
